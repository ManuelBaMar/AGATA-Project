# %% [markdown]
# Notebook dedicado a la realización de una red neuronal que sea capaz de copiar la función de similitud de Wilcoxon, con el objetivo de poder determinar que pares de señales son estadísticamente iguales y cuales no. El objetivo es que esta red neuronal trabaje en el espacio latente generado por el análisis de componetes principales. De esta manera se pretende evaluar la similitud entre señales en el espacio latente.

# %%
###Importamos las librerias necesarias:
##TensorFlow, Keras a partir de TensorFlow; y de Keras además importamos el comando para crear capas
import tensorflow as tf #Importamos TensorFlow
#import tensorflow_hub as hub #Importamos esta libreria que contiene modelos preentrenados para poder importarlos
from tensorflow import keras #Importamos keras desde TensorFlow
from tensorflow.keras import layers #Importamos la funcion para crear capas de redes neuronales desde keras
from tensorflow.keras.models import Model #Importamis la clase Model de tensorflow, lo que permite crear modelos de DL como clases, con arquitecturas más complejas que usar Sequential
from tensorflow.keras.callbacks import EarlyStopping #Importamos la funcion para realizar el earlystopping desde la libreria de callbacks de keras
from tensorflow.keras.models import load_model #Cargamos la funcion para poder importar modelos de machine learning
from tensorflow.keras.utils import plot_model #Cargamos la funcion para poder realizar representaciones de la arquitectura de modelos
from keras.saving import register_keras_serializable #Funcion de queras necesaria para guardar modelos que se hayan definidos como clases

##Importamos keras tuning para poder optimizar los hiperparametros del modelo
import keras_tuner as kt

##Importamos cuda para poder liberar el espacio de la GPU
from numba import cuda

##Importamos Pandas para trabajar con DataFrames
import pandas as pd

##Importamos Numpy para incluir mas funciones matematicas
import numpy as np

##Importamos la lireria itertools para tener herramientas de iteracion sobre diferentes conjuntos
import itertools

##Importamos MatPlotLib para realizar representaciones
import matplotlib.pyplot as plt
from matplotlib import gridspec #Es un paquete de matplotlib que permite realizar figuras de varias subfiguras

##Importamos la funcion display de la libreria IPython.display, que permite mostrar contenido de manera mas enriquecida. Tambien importamos Image para poder mostrar gráficos
from IPython.display import display
from IPython.display import Image

##Importamos varias funciones de las librerias sklearn
from sklearn.model_selection import train_test_split #Es una función que se utiliza para dividir un conjunto de datos en conjuntos de entrenamiento y prueba de forma aleatoria.
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score #Funciones para evaluar el rendimiento de modelos de clasificcacion: accuracy_score() fraccion de muestras clasificadas correctaente (precision del modelo), precision_score() precision para una clase en particular, recall_score() sensibilidad para cada clase (tasa de verdaderos positivos)
from sklearn.metrics.pairwise import cosine_similarity #Importamos la función necesaria para calcular la similaridad coseno
from sklearn.metrics import roc_curve, roc_auc_score #Imoprtamos las funciones necesarias para poder realizar el cálculo de la curva ROC

##Importamos la función para realizar el submuestreo aleatorio de la clase mayoritaria de la biblioteca imbalance-learning
from imblearn.under_sampling import RandomUnderSampler

#Importamos la libreria joblib para poder cargar modelos generados con scikit-learn como puede ser una PCA
import joblib

##Importamos el modulo time para poder medir el tiempo de ejecución del codigo
import time

##Immportamos el generador de números aleatorios
import random

##Importamos la biblioteca os para poder configurar la sesion de tensorflow
import os

##Importamos la librería multiprocessing para poder paralelizar el computo entre los distintos núcleos de la CPU
import multiprocessing as mp

##Importamos archivos .py propios que contienen los diferentes modelo que deseamos utilizar 
import sys
sys.path.append('Digiopt/') #Es necesario agregar esta linea para que "import" busque por defecto dentro del directorio que se especifica
from AGATALib import modelos #Archivo .py que contiene los diferentes modelos que hemos creado
from AGATALib import testwcore #Archivo .py que contiene la implemenación del algoritmo de comparacion basado en el test de Wilcoxon
# Out:
# 2024-07-19 07:22:28.280053: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-19 07:22:28.323303: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-19 07:22:29.054985: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Inicio de la sesión de Tensorflow para limitar la memoria de la GPU usada.

# %%
##Funcion para establecer la sesion de tensorflow de tal manera que solo use un tercio de la memoria de la GPU. Siempre ejecutar esta celda
def set_tf_session(gpu_memory = 0.20):
    #Establecemos la fraccion de memoria de GPU a utilizar en la sesion. Por defecto emplea el 100%
    gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = gpu_memory)
    #Iniciamos la sesión de tensorflow con la fracción de memoria que hemos establecido
    sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))
    return sess

#Iniciamos la sesion con la fraccion de memoria deseada de GPU
set_tf_session()
# Out:
# 2024-07-19 07:22:35.521513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4831 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:3b:00.0, compute capability: 8.6

# %% [markdown]
# Definimos una serie de funciones que pueden ser últiles a lo largo del desarrollo y evaluación de la red neuronal: función para representar los pulsos, función para determinar el tiempo de ejecución, función para normalizar los datos a las escala [0,1], función para convertier en un tensor de Tensorflow un DataFrame de Pandas de tal manera que se encuentren en el formato requerido por Tensorflow y la función para pintar las estadísticas de la clasificación.

# %%
##Definimos una funcion para representar de manera comoda dos señales diferentes aleatorias en un mismo grafico, que provengan del mismo conjunto de datos
def plot_pulsos(data):
    #Generar dos números enteros aleatorios entre 1 y 1708
    n_random = random.randint(1, data.shape[0])
    m_random = random.randint(1, data.shape[0])
    
    #Representacion de las señales en un plot
    plt.figure(figsize = (10, 5))
    plt.plot(data.iloc[n_random], label = "Señal 1", color = "blue")
    plt.plot(data.iloc[m_random], label = "Señal 2", color = "red")
    plt.title('Señal')
    plt.xticks([])
    plt.ylabel('Valor')
    plt.show()

##Función para pasar de segundos a horas, minutos y segundos, para poder comparar tiempos de ejecución
def convertir_segundos(segundos_totales):
    horas = segundos_totales // 3600  # Calcula cuántas horas hay en los segundos dados
    minutos = (segundos_totales % 3600) // 60  # Calcula los minutos restantes
    segundos = segundos_totales % 60  # Calcula los segundos restantes

    return horas, minutos, segundos

##Función para normalizar las señales. Proporciona dos opciones: 1 para normalizar a [0,1] y 2 para normalizar respecto al valor máximo
#Por defecto normaliza a escala [0,1]
def normalizacion(df, tipo = 1):
    #Normalización [0,1]
    if tipo == 1:
        maximos_fila = df.max(axis = 1).to_numpy() #Extraemos el valor máximo de las filas
        minimos_fila = df.min(axis = 1).to_numpy() #Extraemos el valor mínimo de las filas
        df = (df - minimos_fila[:, None])/(maximos_fila[:, None] - minimos_fila[:, None]) #Normalizamos los valores del Dataframe
        return df
    
    #Normalización respecto al máximo
    if tipo == 2:
        maximos_fila = df.max(axis = 1).to_numpy() #Extraemos el valor máximos de las filas
        df = df/maximos_fila[:, None] #Dividimos cada fila por su máximo
        return df
    
##Funcion para cambiar el formato del input del autoencoder y que sea compatible con papas convolucionales 1D
def convert_to_tensor(df):
    #Convertimos el dataframe a un tensor
    tensor = tf.convert_to_tensor(df, dtype = tf.float32)
    #Añadimos la dimension de canal 
    tensor = tf.expand_dims(tensor, axis = 2)
    return tensor

##Definimos una funcion que nos muestre los porcentajes de clasificacion que nos interesa:
def print_stats(predictions, real):
    accuracy = accuracy_score(real, predictions) #Porcentaje de individuos clasificados correctamente
    precision = precision_score(real, predictions) #Proporcion de verdaderos positivos entre todas las observaciones clasificadas como positivas
    recall = recall_score(real, predictions) #Proporcion de verdaderos positivos entre todas las observaciones clasificadas correctamente
    score_f1 = f1_score(real, predictions) #Computa la métrica f1_score, que representa una medida armónica del recall y la precision. Medida comprendida entre 0 y 1.
    print("Accuracy: {}".format(accuracy))
    print("Precision: {}".format(precision))
    print("Recall: {}".format(recall))
    print("F1 score: {}".format(score_f1))

# %% [markdown]
# Paralelizamos el proceso de emparejamiento de señales, de tal manera que se pueda realizar de manera más optima el emparejamiento una vez se tengan las señales en el espacio de dimension latente.

# %%
##En primer lugar debemos definir el proceso que va a realizar cada uno de los nodos de computo.
#En este caso, dicho proceso va a ser coger un par de íncides y concatenar los pulsos correspondientes.
def process_chunk_concat(chunk, df):
    #Preparamos una lista vacia donde vamos a ir añadiendo cada uno de los pares de pulsos concatenados
    new_rows = []

    #Iteramos sobre los pares de indices contenidos en chunk
    for index1, index2 in chunk:
        #Extraemos los pulsos asociados a cada uno de los indices
        pulse1 = df.loc[index1].values
        pulse2 = df.loc[index2].values
        #Concatenamos los valores de ambos pulsos en una sola fila, junto el índice correspondiente a cada pulso
        concatenated_pulses = [index1, index2] + list(np.concatenate([pulse1, pulse2]))
        #Agregamos los pulsos concatenados a la lista
        new_rows.append(concatenated_pulses)
    
    #Devolvemos los pares de pulsos para un chunk de indices
    return new_rows

##Definimos la función que va a paralelizar el proceso de computo. Va a tomar como argumento el DataFrame que contiene los pulsos que se desean emparejar,
#un booleano que indica si se quiere devolver el DataFrame de pulsos emparejados y el numero de cores de CPU que se desean utilizar (por defecto todos los disponibles)
def parallel_paired_pulses(df, return_df = False, num_workers = None):
    #Calculamos las posibles combinaciones de pulsos mediante los indices
    paired_index = list(itertools.combinations(df.index, 2))

    #Comprobamos si se debe devolver el DataFrame de pulsos emparejados
    if return_df == False:
        return paired_index
    else:
        #Si se quiere que se devuelva el DataFrame se establece el numero de nucleao de computo
        num_workers = num_workers or (mp.cpu_count() -5)

        #Se divide la lista de pares de indices en tantas partes como nodos de computo se han definido
        chunk_size = len(paired_index) // num_workers
        #Definimos la lista de chunks de indices a los que aplicaremos el proceso
        chunks = [paired_index[i : i + chunk_size] for i in range(0, len(paired_index), chunk_size)] 

        #Creamos el pool de procesos, igual al número de trabajadores, que se va a paralelizar entre todos los nodos de computo
        with mp.Pool(processes = num_workers) as pool:
            #Empleamos el metodo .starmap() dado que este permite emplear funciones que presentan mas de un argumento, como es neustro caso
            results = pool.starmap(process_chunk_concat, [(chunk, df) for chunk in chunks])

        #Combinamos todos los resultados obtenidos en el proceso de emparejamiento
        new_rows = [row for chunk in results for row in chunk]

        #Combertimos la lista que contiene todas las combinaciones de pares de pulsos en un DataFrame y lo devolvemos como resultado de la función
        columns = ["id_1", "id_2"] + list(range(df.shape[1]*2))
        combined_df = pd.DataFrame(new_rows, columns = columns)
        return paired_index, combined_df

# %%
##En primer lugar definimos el proceso que va a realizar el cálculo para cada uno de los chunks de los pares de señales.
#En este caso cada proceso es comparar los pulsos de ese chunk
def process_chunk_compare(chunk):
    chunk["Test_W"] = chunk.apply(testwcore.compare_pulses, axis = 1)
    return chunk

##Definimos la función que va a paralelizar el proceso de computo. Toma como argumentos un DataFrame y el número de nodos de computo que se desean utilizar.
#Por defecto el número de nodos de computo se establece en None, de tal manera que luego se tomen todos los nodos de computo disponibles si no se ha indicado lo contrario
def parallel_compare_pulses(df, num_workers = None):
    #Si num_workers = None entonces num_workrs = mp.cpu_count(), es decir, el número de nodos de computo disponibles
    num_workers = num_workers or (mp.cpu_count() - 5)
    #Calculamos el tamaño que debe tener cada chunk del DataFrame
    chunk_size = len(df) // num_workers 

    #Segmentamos el DataFrame entero en cada uno de los chunks que vamos a analizar con cada nodo de computo
    chunks = [df.iloc[i : i + chunk_size].copy() for i in range(0, len(df), chunk_size)]

    #Creamos el pool de procesos, igual al número de trabajadores, que se va a paralelizar entre todos los nodos de cómputo
    with mp.Pool(processes = num_workers) as pool:
        results = pool.map(process_chunk_compare, chunks)
    
    #Combinamos todos los resultados dados por la paralelizacion del cálculo en un solo DataFrame y lo devolvemos como resultado de la función
    combined_results = pd.concat(results)
    return combined_results

# %% [markdown]
# Desde la biblioteca AGATALib.modelos cargamos los diferentes arquitecturas de autoencoder que hemos definido. Además, a traves de la ruta de archivos a "./Models" cargamos los modelos ".keras" para que en conjunto podamos importar cualquiera de los modelos sin problema junto con los pesos resultantes del entrenamiento en los notebooks en los que se han creado cada modelo. A mayores, cargamos la transformación PCA realizada con scikit-learn ayudandonos de la biblioteca joblib.

# %%
##Cargamos los diferentes modelos de Autoencoder que hemos definido junto con los pesos resultantres del entrenamiento. Congelamos los pesos de los diferentes modelos.
#Modelo basado en la arquitectura de Liverpool
autoencoder_v1 = load_model("/home/jupyter-manuel/Digiopt/Models/AE_V1_HyperModel_Hyperband.keras", custom_objects = {'AE_V1': modelos.Autoencoder_V1})
autoencoder_v1.trainable = False
#Primer modelo de autoencoder convolucional
c_autoencoder_1 = load_model("/home/jupyter-manuel/Digiopt/Models/CAE_1_HyperModel_Hyperband.keras", custom_objects = {'CAE_1': modelos.Convolutional_AE1})
c_autoencoder_1.trainable = False
#Segundo modelo de autoencoder convolucional
c_autoencoder_2 = load_model("/home/jupyter-manuel/Digiopt/Models/CAE_2_HyperModel_Hyperband.keras", custom_objects = {'CAE_2': modelos.Convolutional_AE2})
c_autoencoder_2.trainable = False

##Cargamos tambien la transformación PCA.
pca = joblib.load("/home/jupyter-manuel/Digiopt/Models/PCA_model.joblib")
# Out:
# 2024-07-19 07:22:48.852705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4831 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:3b:00.0, compute capability: 8.6

# %% [markdown]
# Cargamos los conjuntos de datos necesarios y los preparamos adecuadamente para poder entrenar la red neuronal de clasificación, reduciendoles la dimensión.

# %%
##Cargamos el conjunto de datos con el que vamos a trabajar, que en este caso son un conjunto de señales del core de AGATA y el conjunto de señales de ya emparejadas y evaluadas con el test de Wilcoxon
#Señales core de AGATA
url_1 = "/home/jupyter-manuel/Digiopt/Data/Core_signal.dat"
core_signals = pd.read_csv(url_1, sep = "\t", header = "infer", dtype = np.float64, chunksize = None)
#Señales emparejadas y evaluadas con el test de Wilcoxon
url_2 = "/home/jupyter-manuel/Digiopt/Data/2000_Paired_pulses_test_wilcoxon.dat"
paired_pulses_w = pd.read_csv(url_2, sep = "\t", header = "infer", dtype = np.float64, index_col = 0, chunksize = None)

##Extraemos las primeras 2000 señales del core ya que son a las que se les ha aplicado el test de Wilcoxon (lo que implica aproximadamente 2000000 de comparaciones)
sample_core = core_signals.head(2000)
#Además, normalizamos la muestra extraida para poder trabajar con ella
sample_norm = normalizacion(sample_core)

##Pasamos a reducir la dimensión de las señales que vamos a emplear como muestra en el espacio de dimensión reducida
#Como método de reducción de la dimensión vamos a emplear el análisis de componetes principales (PCA).
encoded_sample = pca.transform(sample_norm)
#Lo convertimos en un DataFrame por comodidad
encoded_sample_df = pd.DataFrame(encoded_sample)

##Extraemos la caracteristica que pretendemos predecir, que en este caso es la evaluacion del test de wilcoxon para pares de señales, que estan contenidas en el DataFrame paired_pulses_w
target_w = paired_pulses_w["Test_W"]

# %% [markdown]
# Emparejamos las señales en el espacio de dimensión reducida, de tal manera que generemos todos los posibles pares de combinaciones de dos elementos sin repetición, asociadas a la variable binaria que queremos predecir mediante una red neuronal de clasificación. Añadimos la variable de clasificación y eliminamos todas las columnas que correspondan a valores nulos en todas las componetes.

# %%
##Llamamos a la función parallel_paired_pulses() para generar todas las posibles combinaciones
start = time.time()
index_paired, paired_pulses = parallel_paired_pulses(encoded_sample_df, return_df = True)
end = time.time()
#Determinamos el tiempo de ejecución
horas, minutos, segundos = convertir_segundos(end - start)
print(f"{horas} horas, {minutos} minutos, {segundos} segundos")

##Una vez generados los pares de pulsos, añadimos la columna asocada a la comparación dada por el test de Wilcoxon
paired_pulses["Test_W"] = target_w

##Eliminamos las columnas cuyas neuronas no guardan información, es decir, que todas las filas son cero
#Eliminar columnas donde todas las filas son ceros, generando el DataFrame con el que vamos a trabajar.
df = paired_pulses.loc[:, ~(paired_pulses == 0).all()]
display(df)
# Out:
# 0.0 horas, 0.0 minutos, 45.267168283462524 segundos
#          id_1  id_2         0         1         2         3         4  \
# 0           0     1 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 1           0     2 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 2           0     3 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 3           0     4 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 4           0     5 -1.423136 -0.265789  0.040266  0.015396  0.078928
# ...       ...   ...       ...       ...       ...       ...       ...
# 1998995  1996  1998  0.051237  0.035905 -0.074181  0.209760 -0.109370
# 1998996  1996  1999  0.051237  0.035905 -0.074181  0.209760 -0.109370
# 1998997  1997  1998 -0.085714  0.152075  0.104114  0.003109 -0.105956
# 1998998  1997  1999 -0.085714  0.152075  0.104114  0.003109 -0.105956
# 1998999  1998  1999 -0.062610  0.465922 -0.029872 -0.073622  0.047570
#
#                 5         6         7  ...        11        12        13  \
# 0       -0.038234 -0.024623  0.043735  ... -0.400021  0.136286 -0.014539
# 1       -0.038234 -0.024623  0.043735  ...  0.055034  0.004448 -0.003874
# 2       -0.038234 -0.024623  0.043735  ...  0.232005 -0.170447  0.141669
# 3       -0.038234 -0.024623  0.043735  ...  0.525184 -0.073860 -0.108725
# 4       -0.038234 -0.024623  0.043735  ...  0.107793  0.141648 -0.029411
# ...           ...       ...       ...  ...       ...       ...       ...
# 1998995  0.026376  0.065468 -0.002180  ...  0.465922 -0.029872 -0.073622
# 1998996  0.026376  0.065468 -0.002180  ...  0.102860  0.151223 -0.159085
# 1998997 -0.019450  0.005264 -0.000743  ...  0.465922 -0.029872 -0.073622
# 1998998 -0.019450  0.005264 -0.000743  ...  0.102860  0.151223 -0.159085
# 1998999 -0.056126  0.040614  0.046573  ...  0.102860  0.151223 -0.159085
#
#                14        15        16        17        18        19  Test_W
# 0        0.057032 -0.061143 -0.052853 -0.028868 -0.022931 -0.035254     0.0
# 1        0.001153 -0.063722 -0.082718  0.014566 -0.003356 -0.005774     0.0
# 2        0.007719  0.071237  0.029597 -0.030013 -0.047957 -0.014006     0.0
# 3        0.077526 -0.030123 -0.007363  0.031100  0.002488 -0.016640     0.0
# 4       -0.126074  0.027198  0.042357 -0.042471 -0.009883  0.002967     0.0
# ...           ...       ...       ...       ...       ...       ...     ...
# 1998995  0.047570 -0.056126  0.040614  0.046573  0.053386 -0.022502     0.0
# 1998996 -0.059181 -0.038800  0.049795 -0.015999 -0.053573  0.004505     0.0
# 1998997  0.047570 -0.056126  0.040614  0.046573  0.053386 -0.022502     0.0
# 1998998 -0.059181 -0.038800  0.049795 -0.015999 -0.053573  0.004505     0.0
# 1998999 -0.059181 -0.038800  0.049795 -0.015999 -0.053573  0.004505     0.0
#
# [1999000 rows x 23 columns]

# %% [markdown]
# Dado que las clases estan muy desbalanceadas, ya que el número de posibles combinaciones de pulsos que resultan como estadísticamente iguales es un 10% del total de combinaciones, vamos a emplear tecnicas de imbalance-learning para tratar de mitigar dicho efecto. La técnica que vamos a emplear es submuestrear la clase mayoritaria eliminando muestras aleatorias. Para ello vamos a emplear la clase RandomUnderSampling.

# %%
##En primer lugar instanciamos la clase asociada al RandomUnderSampling. Con el argumento sampling_strategy podemos indicar el ratio de la clase minoritaria y con el argumento random_state fijamos la semilla aleatoria
rus = RandomUnderSampler(sampling_strategy = 0.4, random_state = 0)

#Genearamos el conjunto de datos: tanto las caracteristicas como la etiqueta que identifica cada clase 
X = df.drop(["Test_W"], axis = 1)
#Convertimos todos los nombres de las caracteristicas a cadenas de texto
X.columns = X.columns.astype(str)
y = df["Test_W"]
print(f"Numero de señales en la muestra: {len(X)}. \nRecuento de clases en la muestra inicial: \n{y.value_counts()}")
print("\n")

#Ajustamos la transformación del submuestreo de la clase minoritaria y la aplicamos a los datos seleccionados
X_sub, y_sub = rus.fit_resample(X, y)
print(f"Numero de señales en la muestra submuestreada: {len(X_sub)}. \nRecuento de clases en la muestra submuestreada: \n{y_sub.value_counts()}")

#Combinar las características y las etiquetas submuestreadas en un nuevo DataFrame
df_resampled = pd.concat([pd.DataFrame(X_sub, columns=X.columns), pd.DataFrame(y_sub, columns=["Test_W"])], axis=1)
#Ordenamos el Dataframe en base al indice de las filas
df_resampled = df_resampled.sort_index()
#Volvemos a cambiar a enteros el nombre de las columnas asociados a números
column_mapping = {"1": 1, "4": 4, "8": 8, "11": 11, "14": 14, "18": 18}
df_resampled = df_resampled.rename(columns = column_mapping)
display(df_resampled)
# Out:
# Numero de señales en la muestra: 1999000.
# Recuento de clases en la muestra inicial:
# Test_W
# 0.0    1795558
# 1.0     203442
# Name: count, dtype: int64
#
#
# Numero de señales en la muestra submuestreada: 712047.
# Recuento de clases en la muestra submuestreada:
# Test_W
# 0.0    508605
# 1.0    203442
# Name: count, dtype: int64
#          id_1  id_2         0         1         2         3         4  \
# 0           0     1 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 2           0     3 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 7           0     8 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 10          0    11 -1.423136 -0.265789  0.040266  0.015396  0.078928
# 11          0    12 -1.423136 -0.265789  0.040266  0.015396  0.078928
# ...       ...   ...       ...       ...       ...       ...       ...
# 1998970  1991  1998 -0.606416  0.072031  0.003102  0.041936 -0.060191
# 1998985  1994  1995  0.944450 -0.015556 -0.169694  0.251683 -0.201297
# 1998991  1995  1997 -1.125678  0.076913  0.127339 -0.105302  0.062586
# 1998996  1996  1999  0.051237  0.035905 -0.074181  0.209760 -0.109370
# 1998999  1998  1999 -0.062610  0.465922 -0.029872 -0.073622  0.047570
#
#                 5         6         7  ...        11        12        13  \
# 0       -0.038234 -0.024623  0.043735  ... -0.400021  0.136286 -0.014539
# 2       -0.038234 -0.024623  0.043735  ...  0.232005 -0.170447  0.141669
# 7       -0.038234 -0.024623  0.043735  ... -0.386302  0.009223  0.086653
# 10      -0.038234 -0.024623  0.043735  ... -0.163114  0.051975 -0.044724
# 11      -0.038234 -0.024623  0.043735  ...  0.220294 -0.150932 -0.043980
# ...           ...       ...       ...  ...       ...       ...       ...
# 1998970  0.074784  0.010636 -0.039523  ...  0.465922 -0.029872 -0.073622
# 1998985 -0.022527  0.060255  0.079105  ...  0.076913  0.127339 -0.105302
# 1998991 -0.021551 -0.014726  0.016803  ...  0.152075  0.104114  0.003109
# 1998996  0.026376  0.065468 -0.002180  ...  0.102860  0.151223 -0.159085
# 1998999 -0.056126  0.040614  0.046573  ...  0.102860  0.151223 -0.159085
#
#                14        15        16        17        18        19  Test_W
# 0        0.057032 -0.061143 -0.052853 -0.028868 -0.022931 -0.035254     0.0
# 2        0.007719  0.071237  0.029597 -0.030013 -0.047957 -0.014006     0.0
# 7       -0.193023 -0.139927 -0.003243  0.017039  0.023181  0.014815     0.0
# 10       0.091633 -0.078110 -0.009918  0.034678 -0.000722  0.029622     1.0
# 11       0.098591  0.030111 -0.030488  0.001852  0.000647  0.025706     0.0
# ...           ...       ...       ...       ...       ...       ...     ...
# 1998970  0.047570 -0.056126  0.040614  0.046573  0.053386 -0.022502     0.0
# 1998985  0.062586 -0.021551 -0.014726  0.016803  0.025258  0.003810     0.0
# 1998991 -0.105956 -0.019450  0.005264 -0.000743  0.000664 -0.003656     0.0
# 1998996 -0.059181 -0.038800  0.049795 -0.015999 -0.053573  0.004505     0.0
# 1998999 -0.059181 -0.038800  0.049795 -0.015999 -0.053573  0.004505     0.0
#
# [712047 rows x 23 columns]

# %% [markdown]
# Generamos los conjuntos de datos necesarios para entrenar el modelo: entrenamiento y validación. Las proporciones empleadas son: 80% para el conjunto de entrenamiento y 20% para el conjunto de validación. Se va a mantener la proporcion de similitudes positivas y similitudes negativas en cada conjunto de datos definido, mediante el argumento stratify de la función train_test_split().

# %%
##Separamos las atributos de la va carcateristica que queremos predecir. Guardamos en otra variable los identificadores de los emparejamientos
X = df_resampled.drop(["id_1", "id_2", "Test_W"], axis = 1)
ids = df_resampled[["id_1", "id_2"]]
y = df_resampled["Test_W"]

#Separamos cada uno de los DataFrames en conjunto de entrenamiento y validación, con las proporciones indicadas y manteniendo la proporción de cada categoría en la variable que deseamos predecir
X_train, X_valid, y_train, y_valid, ids_train, ids_valid = train_test_split(X, y, ids, train_size = 0.80, stratify = y)

# %% [markdown]
# Pasamos a definir el HyperModel que queremos entrenar como modelo de clasificación. Para ello, vamos a definir un modelo basado en capas densas, en el cual tanto el número de capas densas como el número de unidades en cada capa se definirán como hiperparámetros variables de tal manera que ajustaremos sus valores mediante el método RandomSearch(). Otros hiperparámetros que se van a definir son: las penalizaciones lineales y cuadráticas aplicadas a cada capa y el learning rate. Una vez optimizados los parámetros definidos por alguno de los métodos pasaremos al entrenamiento del modelo para detertminar los pesos de la red.

# %%
##Pasamos a definir el modelo de red neuronal que va a desempeñar la tarea de clasificar los pares de señales en estadisticamente iguales o no, copiando el criterio de clasificación dado por el test de Wilcoxon
@register_keras_serializable() #Necesario añadirlo justo antes de definir el modelo como una clase para poder guardarlo correctamente una vez entrenado.
class Classifier_NN(Model): #La clase hereda de la clase padre Model de TensorFlowç
    #Creamos la funcion que inicializa el modelo de red neuronal
    #Como argumento pasamos un diccionario que contiene todos los hyperparametros requeridos por el mdoelo
    def __init__(self, hyper_params, **kwargs):
        #Inicializamos la clase padre de lal que estamos heredando propiedades para que el modelo funcione correctaente
        super(Classifier_NN, self).__init__(**kwargs)
        #Definimos las caracteristicas de las diferentes capas mediante hiperparametros del modelo
        self.hyper_params = hyper_params #Definimos el diccionario de hiperparametros como un atributo de la clase
        self.num_layers = self.hyper_params["num_layers"] #Definimos como atributo de la clase el número de capas densas del clasificador
        self.units_layers = self.hyper_params["units_layers"] #Definimos como atributo del modelo la lista que contiene el número de neuronas asociadas a cada capa densa
        self.l1_penalty = self.hyper_params["l1_penalty"] #Definimos como atributo de la clase la regularización lineal aplicada a las capas
        self.l2_penalty = self.hyper_params["l2_penalty"] #Definimos como atributo de la clase la regularizacion cuadrática aplicada a las capas

        #Llamamos al constructor del modelo para definir la red neuronal
        self.classifier = self.__builder__()

    #Definimos el constructor del modelo. Definimos el modelo como un modelo secuencial de capas
    def __builder__(self):
        #Definimos el modelo secuencial
        model = keras.Sequential([])

        #Añadimos la capa de entrada al modelo secuencial
        model.add(layers.Input(shape = [20]))

        #Añadimos los bloques de capas densas al clasificador en base al número de capas densas definido por el hiperparametro y el número de neuronas asociado a cada capa
        #Los bloques de capas densas constan de una capa densa, una capa BatchNormalization y la capa de activacion ReLU
        for units in self.units_layers:
            model.add(layers.Dense(units = units, kernel_regularizer = keras.regularizers.L1L2(l1 = self.l1_penalty, l2 = self.l2_penalty)))
            model.add(layers.Activation("relu"))
            model.add(layers.Dropout(rate = 0.2))

        #Añadimos la capa de salida al modelo, que consta de una capa densa con una sola neurona y función de activación sigmoid para que haga la funcion de clasisficación binaria
        model.add(layers.Dense(units = 1, activation = "sigmoid", kernel_regularizer = keras.regularizers.L1L2(l1 = self.l1_penalty, l2 = self.l2_penalty)))
            
        #Devolvemos el modelo como resultado del constructor
        return model
        
    #Definimois el método call de la clase del modelo para definir la lógica de las capas
    def call(self, X):
        y = self.classifier(X)
        return y
        
    #Modificamos las funciones de get_config() y from_config() para que la serializacion del modelo al guardarlo se haga correctamente
    def get_config(self):
        config = super(Classifier_NN, self).get_config()
        config.update({
            'hyper_params': self.hyper_params,
        })
        return config

    @classmethod
    def from_config(cls, config):
        hyper_params = config.pop('hyper_params')
        return cls(hyper_params, **config)

# %%
##Una vez definido el modelo de la red debemos definir el HyperModel correspondiente para poder realizar la optimización de hiperparametroa
class Classifier_HyperModel(kt.HyperModel):
    #En pirmer lugar inicializamos la clase, donde vamos a definir el diccionario de hiperparametros, que define el espacio en el que se va a buscar la combinación optima
    def __init__(self):
        self.hyper_params = {
            #Hiperparametros asociados a la arquitectura del modelo
            "num_layers" : lambda hp: hp.Int("num_layers", min_value = 1, max_value = 3, step = 1),
            #El hiperparametro asociado al número de neuronas asociadas a cada capa densa se define dentro del constructor del modelo una vez ya se haya definido el número de capas densas

            #Pesos de las penalizaciones aplicadas al modelo. Combinacion de penalizacion lineal y cuadrática
            "l1_penalty" : lambda hp: hp.Choice("l1_penalty", [1e-4, 1e-5, 1e-6, 1e-7]),
            "l2_penalty" : lambda hp: hp.Choice("l2_penalty", [1e-4, 1e-5, 1e-6, 1e-7]),

            #Hiperparametros asociados al compilador del modelo
            "learning_rate" : lambda hp: hp.Choice("learning_rate", [1e-2, 1e-3, 1e-4]),
        }
    
    #Creamos el método build (constructor del hipermodelo), que va a definir el modelo teniendo en cuenta los diferentes hiperparametros
    def build(self, hp):
        #Definimos el diccionario de hiperparametros para cada trial concreto del proceso de optimización de hiperparametros
        hiperparameters = {key: func(hp) for key, func in self.hyper_params.items()}#Para cada par (key, función que define cada hiperparametro correspondiente) se devuelve el par (key, valor elegido de los posibles del hiperparametro para probar)
        
        #A continuación definimos el hiperparametro asociado al número de neuronas presente en cada bloque de capas densas. Se define como una lista de hiperparametros, construida a partir del hiperparametro asociado al número de capas densas
        hiperparameters["units_layers"] = [hp.Int(f"units_layer_{i}", min_value = 8, max_value = 32,step = 2, sampling = "log") for i in range(hiperparameters["num_layers"])]

        #Definimos el modelo para los hipèrparametros seleccionados en cada trial
        model = Classifier_NN(hiperparameters)

        #Compilamos el modelo teniendo en cuenta los hiperparametros
        model.compile(
            loss = keras.losses.BinaryCrossentropy(),
            optimizer = keras.optimizers.Adam(learning_rate = hiperparameters["learning_rate"]),
            metrics = [keras.metrics.BinaryAccuracy(), keras.metrics.Precision(), keras.metrics.Recall()],
        )
        return model
    
    #Sobreescribimos el metodo de entrenamiento para poder añadir ciertos hiperparametros
    def fit(self, hp, model, *args, **kwargs):
        kwargs['batch_size'] = 100
        kwargs['callbacks'] = [
            EarlyStopping(
                min_delta = 0.001,
                patience = 100,
                restore_best_weights=True
            )
        ]
        return model.fit(*args, **kwargs)

# %% [markdown]
# Una vez definido tanto el esqueleto del modelo como el espacio de hiperparametros, dando lugar al hipermodelo, pasamos a la busqueda de los hiperparametros óptimos mediante el método RandomSearch.

# %%
#Instanciamos el tuner para realizar la busqueda de los hiperparametros sobre el hipermodelo asociado al autoencoder. Primero llamammos al hipermodelo
hipermodel = Classifier_HyperModel()
#Vamos a emplear el RandomSearch, pero tambien estan disponibles: GridSearch, BayesianOptimization, Hyperband y SklearnTuner
tuner = kt.RandomSearch(
    hipermodel,
    objective = "val_precision",
    max_trials = 5,
    executions_per_trial = 2,
    directory = "/home/jupyter-manuel/Digiopt/HyperModels",
    project_name = "Classifier_PCA_tuner",
)
# Out:
# Reloading Tuner from /home/jupyter-manuel/Digiopt/HyperModels/Classifier_PCA_tuner/tuner0.json

# %%
##Realizamos la busqueda de hiperparametros mediante el metodo .search() de la clase tuner

#Definimos el criterio de EarlyStopping para parar el proceso de busqueda de hiperparametros
early_stopping_search = EarlyStopping(
    min_delta = 0.001,
    patience = 100,
    restore_best_weights = True
)

#Iniciamos la busqueda de hiperparametros
tuner.search(
    X_train, y_train,
    validation_data = (X_valid, y_valid),
    callbacks = [early_stopping_search],
    batch_size = 100,
    epochs = 300
)

# %%
##Extraemos los mejores hiperparametros buscados por el HyperModel mediante el método RandomSearch
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

#Resultados obtenidos de los hiperparametros
print("""Los resultados obtenidos para los hiperparametros segun el método RandomSearch son: \n
Número de capas densas = {} \n
Número de neuronas en la 1º capa = {} \n
Número de neuronas en la 2º capa = {} \n
Número de neuronas en la 3º capa = {} \n
Penalizacion L1 = {} \n
Penalizacion L2 = {} \n
Tasa de aprendizaje = {} \n
""".format(best_hps.get("num_layers"), best_hps.get("units_layer_0"),best_hps.get("units_layer_1"),best_hps.get("units_layer_2"), best_hps.get("l1_penalty"), best_hps.get("l2_penalty"), best_hps.get("learning_rate")))

##Una vez realizada la busqueda de hiperparámetros definimos un modelo de decoder que contenga los hiperparametros optimizados
classifier = tuner.hypermodel.build(best_hps)

classifier.classifier.summary()
# Out:
# Los resultados obtenidos para los hiperparametros segun el método RandomSearch son:
#
# Número de capas densas = 3
#
# Número de neuronas en la 1º capa = 32
#
# Número de neuronas en la 2º capa = 32
#
# Número de neuronas en la 3º capa = 32
#
# Penalizacion L1 = 1e-07
#
# Penalizacion L2 = 1e-05
#
# Tasa de aprendizaje = 0.001
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │           672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,817 (11.00 KB)
#  Trainable params: 2,817 (11.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
##Pasamos a entrenar el modelo construido a partir de los hiperparametros optimizados
#Definimos el criterio de convergencia en base a los hiperparametros optimos
early_stopping_fit = EarlyStopping(
    min_delta = 0.001,
    patience = 100,
    restore_best_weights = True
)

#Entrenamos el modelo con lo hiperparametros optimos
history = classifier.fit(
    X_train, y_train,
    validation_data = (X_valid, y_valid),
    callbacks = [early_stopping_fit],
    batch_size = 100,
    epochs = 500,
)
# Out:
# Epoch 1/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - binary_accuracy: 0.6767 - loss: 0.6321 - precision_3: 0.3031 - recall_4: 0.1058 - val_binary_accuracy: 0.7143 - val_loss: 0.5912 - val_precision_3: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7135 - loss: 0.5892 - precision_3: 0.0000e+00 - recall_4: 0.0000e+00 - val_binary_accuracy: 0.7143 - val_loss: 0.5839 - val_precision_3: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7137 - loss: 0.5820 - precision_3: 0.0000e+00 - recall_4: 0.0000e+00 - val_binary_accuracy: 0.7143 - val_loss: 0.5776 - val_precision_3: 1.0000 - val_recall_4: 2.4577e-05
# Epoch 4/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7143 - loss: 0.5752 - precision_3: 0.1248 - recall_4: 3.1941e-06 - val_binary_accuracy: 0.7143 - val_loss: 0.5713 - val_precision_3: 1.0000 - val_recall_4: 9.8307e-05
# Epoch 5/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7145 - loss: 0.5690 - precision_3: 0.2365 - recall_4: 4.1495e-05 - val_binary_accuracy: 0.7144 - val_loss: 0.5655 - val_precision_3: 0.7037 - val_recall_4: 4.6696e-04
# Epoch 6/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7143 - loss: 0.5633 - precision_3: 0.5088 - recall_4: 5.6728e-04 - val_binary_accuracy: 0.7143 - val_loss: 0.5598 - val_precision_3: 0.5175 - val_recall_4: 0.0015
# Epoch 7/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7147 - loss: 0.5577 - precision_3: 0.5545 - recall_4: 0.0022 - val_binary_accuracy: 0.7146 - val_loss: 0.5542 - val_precision_3: 0.5698 - val_recall_4: 0.0049
# Epoch 8/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7149 - loss: 0.5523 - precision_3: 0.6160 - recall_4: 0.0071 - val_binary_accuracy: 0.7157 - val_loss: 0.5493 - val_precision_3: 0.6278 - val_recall_4: 0.0126
# Epoch 9/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7169 - loss: 0.5473 - precision_3: 0.6406 - recall_4: 0.0148 - val_binary_accuracy: 0.7176 - val_loss: 0.5449 - val_precision_3: 0.6495 - val_recall_4: 0.0255
# Epoch 10/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7193 - loss: 0.5429 - precision_3: 0.6630 - recall_4: 0.0281 - val_binary_accuracy: 0.7190 - val_loss: 0.5411 - val_precision_3: 0.6432 - val_recall_4: 0.0368
# Epoch 11/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7206 - loss: 0.5398 - precision_3: 0.6685 - recall_4: 0.0433 - val_binary_accuracy: 0.7223 - val_loss: 0.5378 - val_precision_3: 0.6664 - val_recall_4: 0.0561
# Epoch 12/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7224 - loss: 0.5378 - precision_3: 0.6776 - recall_4: 0.0612 - val_binary_accuracy: 0.7253 - val_loss: 0.5349 - val_precision_3: 0.6803 - val_recall_4: 0.0726
# Epoch 13/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7267 - loss: 0.5333 - precision_3: 0.6865 - recall_4: 0.0760 - val_binary_accuracy: 0.7266 - val_loss: 0.5324 - val_precision_3: 0.6742 - val_recall_4: 0.0834
# Epoch 14/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7278 - loss: 0.5321 - precision_3: 0.6816 - recall_4: 0.0924 - val_binary_accuracy: 0.7294 - val_loss: 0.5301 - val_precision_3: 0.6825 - val_recall_4: 0.0990
# Epoch 15/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7305 - loss: 0.5294 - precision_3: 0.6829 - recall_4: 0.1073 - val_binary_accuracy: 0.7333 - val_loss: 0.5280 - val_precision_3: 0.6837 - val_recall_4: 0.1237
# Epoch 16/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7342 - loss: 0.5262 - precision_3: 0.6835 - recall_4: 0.1234 - val_binary_accuracy: 0.7351 - val_loss: 0.5260 - val_precision_3: 0.6907 - val_recall_4: 0.1320
# Epoch 17/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7351 - loss: 0.5261 - precision_3: 0.6865 - recall_4: 0.1392 - val_binary_accuracy: 0.7360 - val_loss: 0.5242 - val_precision_3: 0.6844 - val_recall_4: 0.1411
# Epoch 18/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7370 - loss: 0.5241 - precision_3: 0.6880 - recall_4: 0.1523 - val_binary_accuracy: 0.7368 - val_loss: 0.5226 - val_precision_3: 0.6875 - val_recall_4: 0.1444
# Epoch 19/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7382 - loss: 0.5219 - precision_3: 0.6812 - recall_4: 0.1595 - val_binary_accuracy: 0.7413 - val_loss: 0.5208 - val_precision_3: 0.6876 - val_recall_4: 0.1731
# Epoch 20/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7404 - loss: 0.5204 - precision_3: 0.6838 - recall_4: 0.1740 - val_binary_accuracy: 0.7390 - val_loss: 0.5193 - val_precision_3: 0.6860 - val_recall_4: 0.1597
# Epoch 21/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7419 - loss: 0.5179 - precision_3: 0.6823 - recall_4: 0.1794 - val_binary_accuracy: 0.7434 - val_loss: 0.5177 - val_precision_3: 0.6848 - val_recall_4: 0.1890
# Epoch 22/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7427 - loss: 0.5172 - precision_3: 0.6788 - recall_4: 0.1909 - val_binary_accuracy: 0.7470 - val_loss: 0.5164 - val_precision_3: 0.6849 - val_recall_4: 0.2119
# Epoch 23/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7445 - loss: 0.5151 - precision_3: 0.6777 - recall_4: 0.1976 - val_binary_accuracy: 0.7482 - val_loss: 0.5151 - val_precision_3: 0.6773 - val_recall_4: 0.2271
# Epoch 24/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7451 - loss: 0.5146 - precision_3: 0.6768 - recall_4: 0.2105 - val_binary_accuracy: 0.7482 - val_loss: 0.5137 - val_precision_3: 0.6840 - val_recall_4: 0.2208
# Epoch 25/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7466 - loss: 0.5131 - precision_3: 0.6811 - recall_4: 0.2131 - val_binary_accuracy: 0.7495 - val_loss: 0.5125 - val_precision_3: 0.6800 - val_recall_4: 0.2330
# Epoch 26/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7465 - loss: 0.5127 - precision_3: 0.6760 - recall_4: 0.2241 - val_binary_accuracy: 0.7492 - val_loss: 0.5113 - val_precision_3: 0.6801 - val_recall_4: 0.2306
# Epoch 27/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7479 - loss: 0.5111 - precision_3: 0.6743 - recall_4: 0.2244 - val_binary_accuracy: 0.7496 - val_loss: 0.5101 - val_precision_3: 0.6860 - val_recall_4: 0.2281
# Epoch 28/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7487 - loss: 0.5097 - precision_3: 0.6738 - recall_4: 0.2317 - val_binary_accuracy: 0.7525 - val_loss: 0.5092 - val_precision_3: 0.6861 - val_recall_4: 0.2466
# Epoch 29/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7500 - loss: 0.5094 - precision_3: 0.6772 - recall_4: 0.2414 - val_binary_accuracy: 0.7525 - val_loss: 0.5081 - val_precision_3: 0.6795 - val_recall_4: 0.2533
# Epoch 30/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7514 - loss: 0.5074 - precision_3: 0.6751 - recall_4: 0.2488 - val_binary_accuracy: 0.7515 - val_loss: 0.5071 - val_precision_3: 0.6880 - val_recall_4: 0.2387
# Epoch 31/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7522 - loss: 0.5079 - precision_3: 0.6796 - recall_4: 0.2575 - val_binary_accuracy: 0.7534 - val_loss: 0.5061 - val_precision_3: 0.6829 - val_recall_4: 0.2554
# Epoch 32/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7532 - loss: 0.5067 - precision_3: 0.6794 - recall_4: 0.2640 - val_binary_accuracy: 0.7541 - val_loss: 0.5052 - val_precision_3: 0.6850 - val_recall_4: 0.2581
# Epoch 33/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7537 - loss: 0.5052 - precision_3: 0.6763 - recall_4: 0.2641 - val_binary_accuracy: 0.7556 - val_loss: 0.5043 - val_precision_3: 0.6838 - val_recall_4: 0.2690
# Epoch 34/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7549 - loss: 0.5041 - precision_3: 0.6784 - recall_4: 0.2753 - val_binary_accuracy: 0.7563 - val_loss: 0.5034 - val_precision_3: 0.6782 - val_recall_4: 0.2801
# Epoch 35/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7557 - loss: 0.5032 - precision_3: 0.6762 - recall_4: 0.2815 - val_binary_accuracy: 0.7577 - val_loss: 0.5025 - val_precision_3: 0.6800 - val_recall_4: 0.2869
# Epoch 36/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7566 - loss: 0.5019 - precision_3: 0.6759 - recall_4: 0.2843 - val_binary_accuracy: 0.7559 - val_loss: 0.5019 - val_precision_3: 0.6824 - val_recall_4: 0.2724
# Epoch 37/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7569 - loss: 0.5012 - precision_3: 0.6746 - recall_4: 0.2891 - val_binary_accuracy: 0.7569 - val_loss: 0.5011 - val_precision_3: 0.6838 - val_recall_4: 0.2773
# Epoch 38/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7572 - loss: 0.5009 - precision_3: 0.6738 - recall_4: 0.2916 - val_binary_accuracy: 0.7599 - val_loss: 0.5003 - val_precision_3: 0.6767 - val_recall_4: 0.3057
# Epoch 39/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7585 - loss: 0.5009 - precision_3: 0.6761 - recall_4: 0.3023 - val_binary_accuracy: 0.7608 - val_loss: 0.4996 - val_precision_3: 0.6742 - val_recall_4: 0.3150
# Epoch 40/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7589 - loss: 0.4989 - precision_3: 0.6723 - recall_4: 0.3038 - val_binary_accuracy: 0.7605 - val_loss: 0.4990 - val_precision_3: 0.6773 - val_recall_4: 0.3091
# Epoch 41/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7607 - loss: 0.4976 - precision_3: 0.6766 - recall_4: 0.3104 - val_binary_accuracy: 0.7602 - val_loss: 0.4984 - val_precision_3: 0.6767 - val_recall_4: 0.3075
# Epoch 42/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7602 - loss: 0.4988 - precision_3: 0.6748 - recall_4: 0.3099 - val_binary_accuracy: 0.7610 - val_loss: 0.4978 - val_precision_3: 0.6777 - val_recall_4: 0.3116
# Epoch 43/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7604 - loss: 0.4982 - precision_3: 0.6751 - recall_4: 0.3176 - val_binary_accuracy: 0.7612 - val_loss: 0.4972 - val_precision_3: 0.6781 - val_recall_4: 0.3123
# Epoch 44/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - binary_accuracy: 0.7609 - loss: 0.4969 - precision_3: 0.6721 - recall_4: 0.3165 - val_binary_accuracy: 0.7603 - val_loss: 0.4967 - val_precision_3: 0.6811 - val_recall_4: 0.3026
# Epoch 45/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - binary_accuracy: 0.7613 - loss: 0.4962 - precision_3: 0.6736 - recall_4: 0.3206 - val_binary_accuracy: 0.7602 - val_loss: 0.4962 - val_precision_3: 0.6855 - val_recall_4: 0.2968
# Epoch 46/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - binary_accuracy: 0.7626 - loss: 0.4952 - precision_3: 0.6759 - recall_4: 0.3210 - val_binary_accuracy: 0.7635 - val_loss: 0.4954 - val_precision_3: 0.6763 - val_recall_4: 0.3302
# Epoch 47/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7628 - loss: 0.4951 - precision_3: 0.6733 - recall_4: 0.3302 - val_binary_accuracy: 0.7641 - val_loss: 0.4948 - val_precision_3: 0.6774 - val_recall_4: 0.3330
# Epoch 48/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7631 - loss: 0.4943 - precision_3: 0.6735 - recall_4: 0.3318 - val_binary_accuracy: 0.7649 - val_loss: 0.4943 - val_precision_3: 0.6827 - val_recall_4: 0.3311
# Epoch 49/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7642 - loss: 0.4933 - precision_3: 0.6753 - recall_4: 0.3325 - val_binary_accuracy: 0.7650 - val_loss: 0.4936 - val_precision_3: 0.6772 - val_recall_4: 0.3393
# Epoch 50/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7651 - loss: 0.4926 - precision_3: 0.6763 - recall_4: 0.3401 - val_binary_accuracy: 0.7655 - val_loss: 0.4931 - val_precision_3: 0.6755 - val_recall_4: 0.3451
# Epoch 51/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7655 - loss: 0.4924 - precision_3: 0.6770 - recall_4: 0.3419 - val_binary_accuracy: 0.7651 - val_loss: 0.4926 - val_precision_3: 0.6828 - val_recall_4: 0.3320
# Epoch 52/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7646 - loss: 0.4916 - precision_3: 0.6734 - recall_4: 0.3420 - val_binary_accuracy: 0.7677 - val_loss: 0.4920 - val_precision_3: 0.6777 - val_recall_4: 0.3565
# Epoch 53/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7666 - loss: 0.4914 - precision_3: 0.6758 - recall_4: 0.3514 - val_binary_accuracy: 0.7670 - val_loss: 0.4915 - val_precision_3: 0.6799 - val_recall_4: 0.3488
# Epoch 54/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7664 - loss: 0.4908 - precision_3: 0.6745 - recall_4: 0.3497 - val_binary_accuracy: 0.7671 - val_loss: 0.4911 - val_precision_3: 0.6786 - val_recall_4: 0.3510
# Epoch 55/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7667 - loss: 0.4911 - precision_3: 0.6761 - recall_4: 0.3556 - val_binary_accuracy: 0.7669 - val_loss: 0.4906 - val_precision_3: 0.6813 - val_recall_4: 0.3459
# Epoch 56/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7675 - loss: 0.4899 - precision_3: 0.6764 - recall_4: 0.3568 - val_binary_accuracy: 0.7683 - val_loss: 0.4901 - val_precision_3: 0.6797 - val_recall_4: 0.3572
# Epoch 57/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7675 - loss: 0.4895 - precision_3: 0.6749 - recall_4: 0.3574 - val_binary_accuracy: 0.7669 - val_loss: 0.4897 - val_precision_3: 0.6821 - val_recall_4: 0.3451
# Epoch 58/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7679 - loss: 0.4887 - precision_3: 0.6758 - recall_4: 0.3619 - val_binary_accuracy: 0.7680 - val_loss: 0.4893 - val_precision_3: 0.6805 - val_recall_4: 0.3544
# Epoch 59/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7686 - loss: 0.4877 - precision_3: 0.6758 - recall_4: 0.3598 - val_binary_accuracy: 0.7706 - val_loss: 0.4889 - val_precision_3: 0.6755 - val_recall_4: 0.3792
# Epoch 60/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7673 - loss: 0.4891 - precision_3: 0.6729 - recall_4: 0.3672 - val_binary_accuracy: 0.7681 - val_loss: 0.4883 - val_precision_3: 0.6819 - val_recall_4: 0.3533
# Epoch 61/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7680 - loss: 0.4880 - precision_3: 0.6725 - recall_4: 0.3659 - val_binary_accuracy: 0.7698 - val_loss: 0.4879 - val_precision_3: 0.6833 - val_recall_4: 0.3623
# Epoch 62/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7693 - loss: 0.4869 - precision_3: 0.6762 - recall_4: 0.3685 - val_binary_accuracy: 0.7685 - val_loss: 0.4875 - val_precision_3: 0.6850 - val_recall_4: 0.3516
# Epoch 63/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7697 - loss: 0.4868 - precision_3: 0.6770 - recall_4: 0.3733 - val_binary_accuracy: 0.7700 - val_loss: 0.4869 - val_precision_3: 0.6816 - val_recall_4: 0.3657
# Epoch 64/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7704 - loss: 0.4858 - precision_3: 0.6761 - recall_4: 0.3761 - val_binary_accuracy: 0.7724 - val_loss: 0.4865 - val_precision_3: 0.6778 - val_recall_4: 0.3878
# Epoch 65/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7717 - loss: 0.4852 - precision_3: 0.6806 - recall_4: 0.3794 - val_binary_accuracy: 0.7734 - val_loss: 0.4861 - val_precision_3: 0.6751 - val_recall_4: 0.3988
# Epoch 66/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7721 - loss: 0.4850 - precision_3: 0.6783 - recall_4: 0.3819 - val_binary_accuracy: 0.7724 - val_loss: 0.4857 - val_precision_3: 0.6808 - val_recall_4: 0.3831
# Epoch 67/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7706 - loss: 0.4859 - precision_3: 0.6763 - recall_4: 0.3813 - val_binary_accuracy: 0.7733 - val_loss: 0.4853 - val_precision_3: 0.6774 - val_recall_4: 0.3943
# Epoch 68/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7717 - loss: 0.4856 - precision_3: 0.6769 - recall_4: 0.3872 - val_binary_accuracy: 0.7744 - val_loss: 0.4852 - val_precision_3: 0.6782 - val_recall_4: 0.4000
# Epoch 69/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7722 - loss: 0.4846 - precision_3: 0.6766 - recall_4: 0.3873 - val_binary_accuracy: 0.7733 - val_loss: 0.4847 - val_precision_3: 0.6805 - val_recall_4: 0.3892
# Epoch 70/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7728 - loss: 0.4841 - precision_3: 0.6785 - recall_4: 0.3893 - val_binary_accuracy: 0.7743 - val_loss: 0.4843 - val_precision_3: 0.6797 - val_recall_4: 0.3973
# Epoch 71/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7721 - loss: 0.4850 - precision_3: 0.6766 - recall_4: 0.3912 - val_binary_accuracy: 0.7735 - val_loss: 0.4841 - val_precision_3: 0.6828 - val_recall_4: 0.3872
# Epoch 72/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7731 - loss: 0.4834 - precision_3: 0.6786 - recall_4: 0.3921 - val_binary_accuracy: 0.7738 - val_loss: 0.4837 - val_precision_3: 0.6827 - val_recall_4: 0.3890
# Epoch 73/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7729 - loss: 0.4837 - precision_3: 0.6770 - recall_4: 0.3912 - val_binary_accuracy: 0.7758 - val_loss: 0.4836 - val_precision_3: 0.6757 - val_recall_4: 0.4137
# Epoch 74/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7733 - loss: 0.4834 - precision_3: 0.6771 - recall_4: 0.3967 - val_binary_accuracy: 0.7750 - val_loss: 0.4833 - val_precision_3: 0.6813 - val_recall_4: 0.3994
# Epoch 75/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - binary_accuracy: 0.7734 - loss: 0.4832 - precision_3: 0.6772 - recall_4: 0.3969 - val_binary_accuracy: 0.7733 - val_loss: 0.4831 - val_precision_3: 0.6853 - val_recall_4: 0.3819
# Epoch 76/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7735 - loss: 0.4830 - precision_3: 0.6770 - recall_4: 0.4005 - val_binary_accuracy: 0.7736 - val_loss: 0.4828 - val_precision_3: 0.6827 - val_recall_4: 0.3878
# Epoch 77/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7750 - loss: 0.4821 - precision_3: 0.6795 - recall_4: 0.4004 - val_binary_accuracy: 0.7740 - val_loss: 0.4826 - val_precision_3: 0.6838 - val_recall_4: 0.3892
# Epoch 78/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7740 - loss: 0.4820 - precision_3: 0.6765 - recall_4: 0.3996 - val_binary_accuracy: 0.7772 - val_loss: 0.4825 - val_precision_3: 0.6755 - val_recall_4: 0.4242
# Epoch 79/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7748 - loss: 0.4814 - precision_3: 0.6771 - recall_4: 0.4052 - val_binary_accuracy: 0.7739 - val_loss: 0.4821 - val_precision_3: 0.6861 - val_recall_4: 0.3846
# Epoch 80/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7750 - loss: 0.4814 - precision_3: 0.6779 - recall_4: 0.4018 - val_binary_accuracy: 0.7764 - val_loss: 0.4820 - val_precision_3: 0.6782 - val_recall_4: 0.4134
# Epoch 81/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7752 - loss: 0.4813 - precision_3: 0.6773 - recall_4: 0.4088 - val_binary_accuracy: 0.7751 - val_loss: 0.4816 - val_precision_3: 0.6837 - val_recall_4: 0.3961
# Epoch 82/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7749 - loss: 0.4808 - precision_3: 0.6766 - recall_4: 0.4030 - val_binary_accuracy: 0.7748 - val_loss: 0.4815 - val_precision_3: 0.6835 - val_recall_4: 0.3948
# Epoch 83/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7753 - loss: 0.4811 - precision_3: 0.6774 - recall_4: 0.4088 - val_binary_accuracy: 0.7753 - val_loss: 0.4813 - val_precision_3: 0.6825 - val_recall_4: 0.3994
# Epoch 84/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7766 - loss: 0.4802 - precision_3: 0.6802 - recall_4: 0.4091 - val_binary_accuracy: 0.7768 - val_loss: 0.4812 - val_precision_3: 0.6771 - val_recall_4: 0.4181
# Epoch 85/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7768 - loss: 0.4799 - precision_3: 0.6794 - recall_4: 0.4132 - val_binary_accuracy: 0.7765 - val_loss: 0.4810 - val_precision_3: 0.6778 - val_recall_4: 0.4151
# Epoch 86/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7759 - loss: 0.4808 - precision_3: 0.6766 - recall_4: 0.4136 - val_binary_accuracy: 0.7766 - val_loss: 0.4808 - val_precision_3: 0.6777 - val_recall_4: 0.4160
# Epoch 87/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7760 - loss: 0.4799 - precision_3: 0.6773 - recall_4: 0.4129 - val_binary_accuracy: 0.7781 - val_loss: 0.4807 - val_precision_3: 0.6748 - val_recall_4: 0.4309
# Epoch 88/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7762 - loss: 0.4805 - precision_3: 0.6767 - recall_4: 0.4150 - val_binary_accuracy: 0.7772 - val_loss: 0.4805 - val_precision_3: 0.6786 - val_recall_4: 0.4180
# Epoch 89/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7766 - loss: 0.4796 - precision_3: 0.6769 - recall_4: 0.4166 - val_binary_accuracy: 0.7779 - val_loss: 0.4803 - val_precision_3: 0.6772 - val_recall_4: 0.4257
# Epoch 90/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7761 - loss: 0.4801 - precision_3: 0.6753 - recall_4: 0.4178 - val_binary_accuracy: 0.7760 - val_loss: 0.4802 - val_precision_3: 0.6833 - val_recall_4: 0.4027
# Epoch 91/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7765 - loss: 0.4798 - precision_3: 0.6773 - recall_4: 0.4190 - val_binary_accuracy: 0.7783 - val_loss: 0.4800 - val_precision_3: 0.6779 - val_recall_4: 0.4266
# Epoch 92/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7780 - loss: 0.4781 - precision_3: 0.6790 - recall_4: 0.4198 - val_binary_accuracy: 0.7772 - val_loss: 0.4798 - val_precision_3: 0.6807 - val_recall_4: 0.4150
# Epoch 93/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - binary_accuracy: 0.7773 - loss: 0.4791 - precision_3: 0.6773 - recall_4: 0.4163 - val_binary_accuracy: 0.7773 - val_loss: 0.4797 - val_precision_3: 0.6808 - val_recall_4: 0.4154
# Epoch 94/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7769 - loss: 0.4799 - precision_3: 0.6759 - recall_4: 0.4157 - val_binary_accuracy: 0.7778 - val_loss: 0.4795 - val_precision_3: 0.6805 - val_recall_4: 0.4190
# Epoch 95/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7773 - loss: 0.4798 - precision_3: 0.6783 - recall_4: 0.4225 - val_binary_accuracy: 0.7767 - val_loss: 0.4796 - val_precision_3: 0.6862 - val_recall_4: 0.4026
# Epoch 96/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7774 - loss: 0.4792 - precision_3: 0.6779 - recall_4: 0.4222 - val_binary_accuracy: 0.7785 - val_loss: 0.4793 - val_precision_3: 0.6796 - val_recall_4: 0.4253
# Epoch 97/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7781 - loss: 0.4780 - precision_3: 0.6779 - recall_4: 0.4211 - val_binary_accuracy: 0.7781 - val_loss: 0.4792 - val_precision_3: 0.6817 - val_recall_4: 0.4193
# Epoch 98/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7778 - loss: 0.4789 - precision_3: 0.6787 - recall_4: 0.4267 - val_binary_accuracy: 0.7783 - val_loss: 0.4791 - val_precision_3: 0.6830 - val_recall_4: 0.4180
# Epoch 99/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7789 - loss: 0.4784 - precision_3: 0.6785 - recall_4: 0.4252 - val_binary_accuracy: 0.7790 - val_loss: 0.4790 - val_precision_3: 0.6778 - val_recall_4: 0.4319
# Epoch 100/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7784 - loss: 0.4787 - precision_3: 0.6781 - recall_4: 0.4268 - val_binary_accuracy: 0.7790 - val_loss: 0.4789 - val_precision_3: 0.6798 - val_recall_4: 0.4285
# Epoch 101/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7790 - loss: 0.4784 - precision_3: 0.6795 - recall_4: 0.4300 - val_binary_accuracy: 0.7777 - val_loss: 0.4787 - val_precision_3: 0.6851 - val_recall_4: 0.4106
# Epoch 102/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7785 - loss: 0.4779 - precision_3: 0.6793 - recall_4: 0.4282 - val_binary_accuracy: 0.7787 - val_loss: 0.4786 - val_precision_3: 0.6803 - val_recall_4: 0.4253
# Epoch 103/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7783 - loss: 0.4780 - precision_3: 0.6766 - recall_4: 0.4288 - val_binary_accuracy: 0.7790 - val_loss: 0.4785 - val_precision_3: 0.6790 - val_recall_4: 0.4294
# Epoch 104/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7798 - loss: 0.4774 - precision_3: 0.6793 - recall_4: 0.4288 - val_binary_accuracy: 0.7797 - val_loss: 0.4783 - val_precision_3: 0.6793 - val_recall_4: 0.4338
# Epoch 105/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7798 - loss: 0.4771 - precision_3: 0.6793 - recall_4: 0.4321 - val_binary_accuracy: 0.7796 - val_loss: 0.4782 - val_precision_3: 0.6791 - val_recall_4: 0.4332
# Epoch 106/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7779 - loss: 0.4792 - precision_3: 0.6761 - recall_4: 0.4329 - val_binary_accuracy: 0.7785 - val_loss: 0.4782 - val_precision_3: 0.6797 - val_recall_4: 0.4249
# Epoch 107/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7788 - loss: 0.4777 - precision_3: 0.6766 - recall_4: 0.4282 - val_binary_accuracy: 0.7805 - val_loss: 0.4781 - val_precision_3: 0.6761 - val_recall_4: 0.4452
# Epoch 108/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7784 - loss: 0.4787 - precision_3: 0.6763 - recall_4: 0.4306 - val_binary_accuracy: 0.7801 - val_loss: 0.4780 - val_precision_3: 0.6762 - val_recall_4: 0.4422
# Epoch 109/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7798 - loss: 0.4771 - precision_3: 0.6774 - recall_4: 0.4325 - val_binary_accuracy: 0.7805 - val_loss: 0.4779 - val_precision_3: 0.6768 - val_recall_4: 0.4438
# Epoch 110/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - binary_accuracy: 0.7798 - loss: 0.4776 - precision_3: 0.6795 - recall_4: 0.4374 - val_binary_accuracy: 0.7795 - val_loss: 0.4777 - val_precision_3: 0.6807 - val_recall_4: 0.4300
# Epoch 111/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7796 - loss: 0.4772 - precision_3: 0.6776 - recall_4: 0.4368 - val_binary_accuracy: 0.7789 - val_loss: 0.4777 - val_precision_3: 0.6848 - val_recall_4: 0.4189
# Epoch 112/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - binary_accuracy: 0.7791 - loss: 0.4777 - precision_3: 0.6768 - recall_4: 0.4320 - val_binary_accuracy: 0.7791 - val_loss: 0.4776 - val_precision_3: 0.6819 - val_recall_4: 0.4252
# Epoch 113/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7790 - loss: 0.4782 - precision_3: 0.6779 - recall_4: 0.4353 - val_binary_accuracy: 0.7798 - val_loss: 0.4774 - val_precision_3: 0.6808 - val_recall_4: 0.4321
# Epoch 114/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7798 - loss: 0.4771 - precision_3: 0.6768 - recall_4: 0.4340 - val_binary_accuracy: 0.7794 - val_loss: 0.4774 - val_precision_3: 0.6817 - val_recall_4: 0.4279
# Epoch 115/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7800 - loss: 0.4768 - precision_3: 0.6796 - recall_4: 0.4374 - val_binary_accuracy: 0.7797 - val_loss: 0.4774 - val_precision_3: 0.6816 - val_recall_4: 0.4297
# Epoch 116/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7796 - loss: 0.4770 - precision_3: 0.6771 - recall_4: 0.4361 - val_binary_accuracy: 0.7794 - val_loss: 0.4771 - val_precision_3: 0.6820 - val_recall_4: 0.4274
# Epoch 117/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7799 - loss: 0.4765 - precision_3: 0.6766 - recall_4: 0.4402 - val_binary_accuracy: 0.7797 - val_loss: 0.4771 - val_precision_3: 0.6821 - val_recall_4: 0.4289
# Epoch 118/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7797 - loss: 0.4770 - precision_3: 0.6771 - recall_4: 0.4423 - val_binary_accuracy: 0.7798 - val_loss: 0.4770 - val_precision_3: 0.6833 - val_recall_4: 0.4275
# Epoch 119/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7803 - loss: 0.4768 - precision_3: 0.6786 - recall_4: 0.4393 - val_binary_accuracy: 0.7791 - val_loss: 0.4769 - val_precision_3: 0.6823 - val_recall_4: 0.4247
# Epoch 120/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7812 - loss: 0.4769 - precision_3: 0.6798 - recall_4: 0.4405 - val_binary_accuracy: 0.7811 - val_loss: 0.4769 - val_precision_3: 0.6740 - val_recall_4: 0.4527
# Epoch 121/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7802 - loss: 0.4765 - precision_3: 0.6770 - recall_4: 0.4415 - val_binary_accuracy: 0.7798 - val_loss: 0.4768 - val_precision_3: 0.6838 - val_recall_4: 0.4266
# Epoch 122/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7808 - loss: 0.4762 - precision_3: 0.6802 - recall_4: 0.4415 - val_binary_accuracy: 0.7801 - val_loss: 0.4766 - val_precision_3: 0.6806 - val_recall_4: 0.4340
# Epoch 123/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7814 - loss: 0.4760 - precision_3: 0.6795 - recall_4: 0.4436 - val_binary_accuracy: 0.7807 - val_loss: 0.4765 - val_precision_3: 0.6766 - val_recall_4: 0.4454
# Epoch 124/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7805 - loss: 0.4763 - precision_3: 0.6775 - recall_4: 0.4452 - val_binary_accuracy: 0.7811 - val_loss: 0.4764 - val_precision_3: 0.6752 - val_recall_4: 0.4505
# Epoch 125/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7809 - loss: 0.4763 - precision_3: 0.6780 - recall_4: 0.4436 - val_binary_accuracy: 0.7813 - val_loss: 0.4763 - val_precision_3: 0.6776 - val_recall_4: 0.4471
# Epoch 126/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7799 - loss: 0.4763 - precision_3: 0.6748 - recall_4: 0.4375 - val_binary_accuracy: 0.7813 - val_loss: 0.4762 - val_precision_3: 0.6777 - val_recall_4: 0.4470
# Epoch 127/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7808 - loss: 0.4759 - precision_3: 0.6768 - recall_4: 0.4435 - val_binary_accuracy: 0.7813 - val_loss: 0.4762 - val_precision_3: 0.6767 - val_recall_4: 0.4493
# Epoch 128/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7807 - loss: 0.4758 - precision_3: 0.6767 - recall_4: 0.4433 - val_binary_accuracy: 0.7811 - val_loss: 0.4760 - val_precision_3: 0.6777 - val_recall_4: 0.4459
# Epoch 129/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7807 - loss: 0.4760 - precision_3: 0.6775 - recall_4: 0.4436 - val_binary_accuracy: 0.7813 - val_loss: 0.4759 - val_precision_3: 0.6808 - val_recall_4: 0.4419
# Epoch 130/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7808 - loss: 0.4757 - precision_3: 0.6772 - recall_4: 0.4436 - val_binary_accuracy: 0.7816 - val_loss: 0.4760 - val_precision_3: 0.6780 - val_recall_4: 0.4487
# Epoch 131/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7813 - loss: 0.4750 - precision_3: 0.6783 - recall_4: 0.4451 - val_binary_accuracy: 0.7825 - val_loss: 0.4760 - val_precision_3: 0.6761 - val_recall_4: 0.4583
# Epoch 132/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7815 - loss: 0.4761 - precision_3: 0.6780 - recall_4: 0.4479 - val_binary_accuracy: 0.7829 - val_loss: 0.4758 - val_precision_3: 0.6761 - val_recall_4: 0.4608
# Epoch 133/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7809 - loss: 0.4754 - precision_3: 0.6753 - recall_4: 0.4461 - val_binary_accuracy: 0.7822 - val_loss: 0.4756 - val_precision_3: 0.6771 - val_recall_4: 0.4544
# Epoch 134/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7815 - loss: 0.4756 - precision_3: 0.6774 - recall_4: 0.4522 - val_binary_accuracy: 0.7811 - val_loss: 0.4755 - val_precision_3: 0.6833 - val_recall_4: 0.4358
# Epoch 135/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7819 - loss: 0.4749 - precision_3: 0.6800 - recall_4: 0.4488 - val_binary_accuracy: 0.7817 - val_loss: 0.4755 - val_precision_3: 0.6794 - val_recall_4: 0.4470
# Epoch 136/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7815 - loss: 0.4761 - precision_3: 0.6784 - recall_4: 0.4475 - val_binary_accuracy: 0.7824 - val_loss: 0.4754 - val_precision_3: 0.6785 - val_recall_4: 0.4530
# Epoch 137/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7812 - loss: 0.4754 - precision_3: 0.6767 - recall_4: 0.4478 - val_binary_accuracy: 0.7821 - val_loss: 0.4752 - val_precision_3: 0.6779 - val_recall_4: 0.4523
# Epoch 138/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7822 - loss: 0.4749 - precision_3: 0.6782 - recall_4: 0.4512 - val_binary_accuracy: 0.7829 - val_loss: 0.4752 - val_precision_3: 0.6765 - val_recall_4: 0.4602
# Epoch 139/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7825 - loss: 0.4747 - precision_3: 0.6786 - recall_4: 0.4500 - val_binary_accuracy: 0.7812 - val_loss: 0.4751 - val_precision_3: 0.6826 - val_recall_4: 0.4376
# Epoch 140/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - binary_accuracy: 0.7808 - loss: 0.4757 - precision_3: 0.6755 - recall_4: 0.4487 - val_binary_accuracy: 0.7823 - val_loss: 0.4751 - val_precision_3: 0.6817 - val_recall_4: 0.4467
# Epoch 141/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - binary_accuracy: 0.7816 - loss: 0.4751 - precision_3: 0.6775 - recall_4: 0.4513 - val_binary_accuracy: 0.7830 - val_loss: 0.4751 - val_precision_3: 0.6756 - val_recall_4: 0.4626
# Epoch 142/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7823 - loss: 0.4745 - precision_3: 0.6764 - recall_4: 0.4543 - val_binary_accuracy: 0.7808 - val_loss: 0.4750 - val_precision_3: 0.6854 - val_recall_4: 0.4302
# Epoch 143/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7815 - loss: 0.4756 - precision_3: 0.6783 - recall_4: 0.4524 - val_binary_accuracy: 0.7820 - val_loss: 0.4749 - val_precision_3: 0.6819 - val_recall_4: 0.4444
# Epoch 144/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7825 - loss: 0.4745 - precision_3: 0.6785 - recall_4: 0.4517 - val_binary_accuracy: 0.7849 - val_loss: 0.4750 - val_precision_3: 0.6735 - val_recall_4: 0.4797
# Epoch 145/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7827 - loss: 0.4748 - precision_3: 0.6782 - recall_4: 0.4561 - val_binary_accuracy: 0.7822 - val_loss: 0.4747 - val_precision_3: 0.6828 - val_recall_4: 0.4442
# Epoch 146/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7827 - loss: 0.4746 - precision_3: 0.6795 - recall_4: 0.4520 - val_binary_accuracy: 0.7825 - val_loss: 0.4748 - val_precision_3: 0.6796 - val_recall_4: 0.4514
# Epoch 147/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7822 - loss: 0.4742 - precision_3: 0.6785 - recall_4: 0.4525 - val_binary_accuracy: 0.7835 - val_loss: 0.4746 - val_precision_3: 0.6764 - val_recall_4: 0.4643
# Epoch 148/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7813 - loss: 0.4751 - precision_3: 0.6747 - recall_4: 0.4504 - val_binary_accuracy: 0.7827 - val_loss: 0.4745 - val_precision_3: 0.6763 - val_recall_4: 0.4593
# Epoch 149/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7827 - loss: 0.4738 - precision_3: 0.6779 - recall_4: 0.4537 - val_binary_accuracy: 0.7834 - val_loss: 0.4747 - val_precision_3: 0.6770 - val_recall_4: 0.4630
# Epoch 150/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7825 - loss: 0.4744 - precision_3: 0.6775 - recall_4: 0.4552 - val_binary_accuracy: 0.7836 - val_loss: 0.4743 - val_precision_3: 0.6789 - val_recall_4: 0.4602
# Epoch 151/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7823 - loss: 0.4743 - precision_3: 0.6766 - recall_4: 0.4542 - val_binary_accuracy: 0.7836 - val_loss: 0.4742 - val_precision_3: 0.6813 - val_recall_4: 0.4557
# Epoch 152/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7821 - loss: 0.4740 - precision_3: 0.6751 - recall_4: 0.4533 - val_binary_accuracy: 0.7829 - val_loss: 0.4742 - val_precision_3: 0.6796 - val_recall_4: 0.4542
# Epoch 153/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7821 - loss: 0.4744 - precision_3: 0.6777 - recall_4: 0.4574 - val_binary_accuracy: 0.7830 - val_loss: 0.4741 - val_precision_3: 0.6787 - val_recall_4: 0.4568
# Epoch 154/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7831 - loss: 0.4735 - precision_3: 0.6792 - recall_4: 0.4583 - val_binary_accuracy: 0.7850 - val_loss: 0.4744 - val_precision_3: 0.6723 - val_recall_4: 0.4830
# Epoch 155/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7831 - loss: 0.4743 - precision_3: 0.6780 - recall_4: 0.4599 - val_binary_accuracy: 0.7827 - val_loss: 0.4740 - val_precision_3: 0.6823 - val_recall_4: 0.4479
# Epoch 156/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7838 - loss: 0.4731 - precision_3: 0.6788 - recall_4: 0.4556 - val_binary_accuracy: 0.7837 - val_loss: 0.4739 - val_precision_3: 0.6790 - val_recall_4: 0.4607
# Epoch 157/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7828 - loss: 0.4733 - precision_3: 0.6775 - recall_4: 0.4557 - val_binary_accuracy: 0.7816 - val_loss: 0.4739 - val_precision_3: 0.6859 - val_recall_4: 0.4345
# Epoch 158/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7823 - loss: 0.4734 - precision_3: 0.6773 - recall_4: 0.4564 - val_binary_accuracy: 0.7834 - val_loss: 0.4738 - val_precision_3: 0.6747 - val_recall_4: 0.4672
# Epoch 159/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7841 - loss: 0.4721 - precision_3: 0.6789 - recall_4: 0.4594 - val_binary_accuracy: 0.7836 - val_loss: 0.4736 - val_precision_3: 0.6790 - val_recall_4: 0.4601
# Epoch 160/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7834 - loss: 0.4727 - precision_3: 0.6775 - recall_4: 0.4589 - val_binary_accuracy: 0.7828 - val_loss: 0.4735 - val_precision_3: 0.6837 - val_recall_4: 0.4463
# Epoch 161/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7831 - loss: 0.4736 - precision_3: 0.6781 - recall_4: 0.4562 - val_binary_accuracy: 0.7838 - val_loss: 0.4735 - val_precision_3: 0.6771 - val_recall_4: 0.4650
# Epoch 162/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7819 - loss: 0.4751 - precision_3: 0.6768 - recall_4: 0.4648 - val_binary_accuracy: 0.7847 - val_loss: 0.4734 - val_precision_3: 0.6769 - val_recall_4: 0.4714
# Epoch 163/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7826 - loss: 0.4747 - precision_3: 0.6766 - recall_4: 0.4634 - val_binary_accuracy: 0.7838 - val_loss: 0.4734 - val_precision_3: 0.6787 - val_recall_4: 0.4620
# Epoch 164/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7830 - loss: 0.4736 - precision_3: 0.6777 - recall_4: 0.4606 - val_binary_accuracy: 0.7833 - val_loss: 0.4733 - val_precision_3: 0.6818 - val_recall_4: 0.4533
# Epoch 165/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7833 - loss: 0.4728 - precision_3: 0.6782 - recall_4: 0.4589 - val_binary_accuracy: 0.7839 - val_loss: 0.4733 - val_precision_3: 0.6786 - val_recall_4: 0.4633
# Epoch 166/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7830 - loss: 0.4732 - precision_3: 0.6767 - recall_4: 0.4609 - val_binary_accuracy: 0.7821 - val_loss: 0.4732 - val_precision_3: 0.6846 - val_recall_4: 0.4398
# Epoch 167/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7829 - loss: 0.4736 - precision_3: 0.6778 - recall_4: 0.4588 - val_binary_accuracy: 0.7833 - val_loss: 0.4732 - val_precision_3: 0.6795 - val_recall_4: 0.4570
# Epoch 168/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7831 - loss: 0.4732 - precision_3: 0.6765 - recall_4: 0.4613 - val_binary_accuracy: 0.7835 - val_loss: 0.4730 - val_precision_3: 0.6812 - val_recall_4: 0.4553
# Epoch 169/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7834 - loss: 0.4736 - precision_3: 0.6782 - recall_4: 0.4622 - val_binary_accuracy: 0.7833 - val_loss: 0.4729 - val_precision_3: 0.6850 - val_recall_4: 0.4470
# Epoch 170/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7840 - loss: 0.4730 - precision_3: 0.6798 - recall_4: 0.4620 - val_binary_accuracy: 0.7830 - val_loss: 0.4728 - val_precision_3: 0.6777 - val_recall_4: 0.4589
# Epoch 171/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7840 - loss: 0.4722 - precision_3: 0.6782 - recall_4: 0.4638 - val_binary_accuracy: 0.7832 - val_loss: 0.4727 - val_precision_3: 0.6814 - val_recall_4: 0.4528
# Epoch 172/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7838 - loss: 0.4729 - precision_3: 0.6786 - recall_4: 0.4621 - val_binary_accuracy: 0.7836 - val_loss: 0.4726 - val_precision_3: 0.6765 - val_recall_4: 0.4651
# Epoch 173/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7826 - loss: 0.4727 - precision_3: 0.6749 - recall_4: 0.4590 - val_binary_accuracy: 0.7830 - val_loss: 0.4728 - val_precision_3: 0.6830 - val_recall_4: 0.4487
# Epoch 174/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7828 - loss: 0.4734 - precision_3: 0.6756 - recall_4: 0.4634 - val_binary_accuracy: 0.7841 - val_loss: 0.4725 - val_precision_3: 0.6755 - val_recall_4: 0.4700
# Epoch 175/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7832 - loss: 0.4720 - precision_3: 0.6762 - recall_4: 0.4604 - val_binary_accuracy: 0.7838 - val_loss: 0.4727 - val_precision_3: 0.6798 - val_recall_4: 0.4597
# Epoch 176/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7830 - loss: 0.4727 - precision_3: 0.6750 - recall_4: 0.4618 - val_binary_accuracy: 0.7839 - val_loss: 0.4724 - val_precision_3: 0.6776 - val_recall_4: 0.4649
# Epoch 177/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7836 - loss: 0.4712 - precision_3: 0.6768 - recall_4: 0.4638 - val_binary_accuracy: 0.7832 - val_loss: 0.4723 - val_precision_3: 0.6800 - val_recall_4: 0.4559
# Epoch 178/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7834 - loss: 0.4719 - precision_3: 0.6769 - recall_4: 0.4614 - val_binary_accuracy: 0.7833 - val_loss: 0.4723 - val_precision_3: 0.6799 - val_recall_4: 0.4564
# Epoch 179/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7825 - loss: 0.4728 - precision_3: 0.6742 - recall_4: 0.4609 - val_binary_accuracy: 0.7833 - val_loss: 0.4722 - val_precision_3: 0.6808 - val_recall_4: 0.4551
# Epoch 180/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7827 - loss: 0.4726 - precision_3: 0.6756 - recall_4: 0.4639 - val_binary_accuracy: 0.7830 - val_loss: 0.4723 - val_precision_3: 0.6860 - val_recall_4: 0.4433
# Epoch 181/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7836 - loss: 0.4727 - precision_3: 0.6788 - recall_4: 0.4634 - val_binary_accuracy: 0.7831 - val_loss: 0.4722 - val_precision_3: 0.6843 - val_recall_4: 0.4473
# Epoch 182/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7842 - loss: 0.4714 - precision_3: 0.6770 - recall_4: 0.4618 - val_binary_accuracy: 0.7838 - val_loss: 0.4722 - val_precision_3: 0.6799 - val_recall_4: 0.4601
# Epoch 183/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7842 - loss: 0.4716 - precision_3: 0.6781 - recall_4: 0.4655 - val_binary_accuracy: 0.7847 - val_loss: 0.4722 - val_precision_3: 0.6751 - val_recall_4: 0.4748
# Epoch 184/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7834 - loss: 0.4722 - precision_3: 0.6762 - recall_4: 0.4674 - val_binary_accuracy: 0.7835 - val_loss: 0.4720 - val_precision_3: 0.6812 - val_recall_4: 0.4553
# Epoch 185/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7833 - loss: 0.4722 - precision_3: 0.6744 - recall_4: 0.4637 - val_binary_accuracy: 0.7849 - val_loss: 0.4721 - val_precision_3: 0.6730 - val_recall_4: 0.4805
# Epoch 186/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7835 - loss: 0.4718 - precision_3: 0.6754 - recall_4: 0.4659 - val_binary_accuracy: 0.7849 - val_loss: 0.4720 - val_precision_3: 0.6745 - val_recall_4: 0.4780
# Epoch 187/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7834 - loss: 0.4720 - precision_3: 0.6748 - recall_4: 0.4649 - val_binary_accuracy: 0.7838 - val_loss: 0.4719 - val_precision_3: 0.6822 - val_recall_4: 0.4557
# Epoch 188/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7827 - loss: 0.4724 - precision_3: 0.6739 - recall_4: 0.4654 - val_binary_accuracy: 0.7842 - val_loss: 0.4719 - val_precision_3: 0.6813 - val_recall_4: 0.4597
# Epoch 189/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7833 - loss: 0.4725 - precision_3: 0.6760 - recall_4: 0.4653 - val_binary_accuracy: 0.7846 - val_loss: 0.4718 - val_precision_3: 0.6787 - val_recall_4: 0.4673
# Epoch 190/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7844 - loss: 0.4723 - precision_3: 0.6774 - recall_4: 0.4686 - val_binary_accuracy: 0.7846 - val_loss: 0.4718 - val_precision_3: 0.6742 - val_recall_4: 0.4764
# Epoch 191/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7844 - loss: 0.4713 - precision_3: 0.6775 - recall_4: 0.4705 - val_binary_accuracy: 0.7842 - val_loss: 0.4718 - val_precision_3: 0.6800 - val_recall_4: 0.4620
# Epoch 192/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7825 - loss: 0.4728 - precision_3: 0.6741 - recall_4: 0.4642 - val_binary_accuracy: 0.7855 - val_loss: 0.4718 - val_precision_3: 0.6733 - val_recall_4: 0.4845
# Epoch 193/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7842 - loss: 0.4710 - precision_3: 0.6754 - recall_4: 0.4648 - val_binary_accuracy: 0.7835 - val_loss: 0.4717 - val_precision_3: 0.6808 - val_recall_4: 0.4560
# Epoch 194/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7839 - loss: 0.4716 - precision_3: 0.6758 - recall_4: 0.4666 - val_binary_accuracy: 0.7841 - val_loss: 0.4717 - val_precision_3: 0.6794 - val_recall_4: 0.4630
# Epoch 195/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7830 - loss: 0.4723 - precision_3: 0.6756 - recall_4: 0.4654 - val_binary_accuracy: 0.7841 - val_loss: 0.4717 - val_precision_3: 0.6791 - val_recall_4: 0.4633
# Epoch 196/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7832 - loss: 0.4726 - precision_3: 0.6738 - recall_4: 0.4686 - val_binary_accuracy: 0.7850 - val_loss: 0.4717 - val_precision_3: 0.6753 - val_recall_4: 0.4768
# Epoch 197/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7833 - loss: 0.4723 - precision_3: 0.6744 - recall_4: 0.4699 - val_binary_accuracy: 0.7849 - val_loss: 0.4717 - val_precision_3: 0.6762 - val_recall_4: 0.4746
# Epoch 198/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7840 - loss: 0.4711 - precision_3: 0.6746 - recall_4: 0.4683 - val_binary_accuracy: 0.7847 - val_loss: 0.4716 - val_precision_3: 0.6759 - val_recall_4: 0.4737
# Epoch 199/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7833 - loss: 0.4714 - precision_3: 0.6731 - recall_4: 0.4688 - val_binary_accuracy: 0.7851 - val_loss: 0.4715 - val_precision_3: 0.6775 - val_recall_4: 0.4731
# Epoch 200/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7826 - loss: 0.4723 - precision_3: 0.6722 - recall_4: 0.4667 - val_binary_accuracy: 0.7832 - val_loss: 0.4716 - val_precision_3: 0.6830 - val_recall_4: 0.4501
# Epoch 201/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7837 - loss: 0.4712 - precision_3: 0.6748 - recall_4: 0.4697 - val_binary_accuracy: 0.7846 - val_loss: 0.4715 - val_precision_3: 0.6779 - val_recall_4: 0.4686
# Epoch 202/500
# ...
# Epoch 434/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7873 - loss: 0.4680 - precision_3: 0.6745 - recall_4: 0.4933 - val_binary_accuracy: 0.7882 - val_loss: 0.4682 - val_precision_3: 0.6728 - val_recall_4: 0.5033
# Epoch 435/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7882 - loss: 0.4680 - precision_3: 0.6769 - recall_4: 0.4944 - val_binary_accuracy: 0.7867 - val_loss: 0.4682 - val_precision_3: 0.6817 - val_recall_4: 0.4756
# Epoch 436/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - binary_accuracy: 0.7879 - loss: 0.4675 - precision_3: 0.6755 - recall_4: 0.4935 - val_binary_accuracy: 0.7881 - val_loss: 0.4680 - val_precision_3: 0.6778 - val_recall_4: 0.4921
# Epoch 437/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - binary_accuracy: 0.7868 - loss: 0.4682 - precision_3: 0.6733 - recall_4: 0.4914 - val_binary_accuracy: 0.7894 - val_loss: 0.4682 - val_precision_3: 0.6704 - val_recall_4: 0.5169
# Epoch 438/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - binary_accuracy: 0.7873 - loss: 0.4682 - precision_3: 0.6737 - recall_4: 0.4955 - val_binary_accuracy: 0.7894 - val_loss: 0.4683 - val_precision_3: 0.6690 - val_recall_4: 0.5203
# Epoch 439/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7878 - loss: 0.4681 - precision_3: 0.6745 - recall_4: 0.4976 - val_binary_accuracy: 0.7878 - val_loss: 0.4680 - val_precision_3: 0.6782 - val_recall_4: 0.4895
# Epoch 440/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7876 - loss: 0.4674 - precision_3: 0.6751 - recall_4: 0.4916 - val_binary_accuracy: 0.7875 - val_loss: 0.4679 - val_precision_3: 0.6786 - val_recall_4: 0.4868
# Epoch 441/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7878 - loss: 0.4678 - precision_3: 0.6752 - recall_4: 0.4940 - val_binary_accuracy: 0.7887 - val_loss: 0.4679 - val_precision_3: 0.6728 - val_recall_4: 0.5072
# Epoch 442/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7878 - loss: 0.4685 - precision_3: 0.6761 - recall_4: 0.4995 - val_binary_accuracy: 0.7877 - val_loss: 0.4679 - val_precision_3: 0.6767 - val_recall_4: 0.4920
# Epoch 443/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7873 - loss: 0.4687 - precision_3: 0.6761 - recall_4: 0.4961 - val_binary_accuracy: 0.7876 - val_loss: 0.4680 - val_precision_3: 0.6766 - val_recall_4: 0.4918
# Epoch 444/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7876 - loss: 0.4690 - precision_3: 0.6767 - recall_4: 0.4951 - val_binary_accuracy: 0.7880 - val_loss: 0.4677 - val_precision_3: 0.6786 - val_recall_4: 0.4904
# Epoch 445/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7884 - loss: 0.4672 - precision_3: 0.6768 - recall_4: 0.4961 - val_binary_accuracy: 0.7876 - val_loss: 0.4678 - val_precision_3: 0.6804 - val_recall_4: 0.4839
# Epoch 446/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7873 - loss: 0.4685 - precision_3: 0.6745 - recall_4: 0.4949 - val_binary_accuracy: 0.7881 - val_loss: 0.4678 - val_precision_3: 0.6757 - val_recall_4: 0.4970
# Epoch 447/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7872 - loss: 0.4683 - precision_3: 0.6747 - recall_4: 0.4962 - val_binary_accuracy: 0.7884 - val_loss: 0.4679 - val_precision_3: 0.6714 - val_recall_4: 0.5081
# Epoch 448/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - binary_accuracy: 0.7884 - loss: 0.4669 - precision_3: 0.6754 - recall_4: 0.4935 - val_binary_accuracy: 0.7867 - val_loss: 0.4678 - val_precision_3: 0.6825 - val_recall_4: 0.4738
# Epoch 449/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - binary_accuracy: 0.7877 - loss: 0.4681 - precision_3: 0.6768 - recall_4: 0.4959 - val_binary_accuracy: 0.7892 - val_loss: 0.4677 - val_precision_3: 0.6730 - val_recall_4: 0.5096
# Epoch 450/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7881 - loss: 0.4677 - precision_3: 0.6757 - recall_4: 0.4967 - val_binary_accuracy: 0.7895 - val_loss: 0.4676 - val_precision_3: 0.6752 - val_recall_4: 0.5074
# Epoch 451/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - binary_accuracy: 0.7877 - loss: 0.4680 - precision_3: 0.6752 - recall_4: 0.4953 - val_binary_accuracy: 0.7870 - val_loss: 0.4677 - val_precision_3: 0.6829 - val_recall_4: 0.4752
# Epoch 452/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7872 - loss: 0.4673 - precision_3: 0.6736 - recall_4: 0.4922 - val_binary_accuracy: 0.7883 - val_loss: 0.4676 - val_precision_3: 0.6763 - val_recall_4: 0.4971
# Epoch 453/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7867 - loss: 0.4680 - precision_3: 0.6736 - recall_4: 0.4929 - val_binary_accuracy: 0.7886 - val_loss: 0.4675 - val_precision_3: 0.6777 - val_recall_4: 0.4959
# Epoch 454/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7883 - loss: 0.4673 - precision_3: 0.6767 - recall_4: 0.4960 - val_binary_accuracy: 0.7887 - val_loss: 0.4675 - val_precision_3: 0.6737 - val_recall_4: 0.5053
# Epoch 455/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7881 - loss: 0.4678 - precision_3: 0.6761 - recall_4: 0.4978 - val_binary_accuracy: 0.7879 - val_loss: 0.4676 - val_precision_3: 0.6780 - val_recall_4: 0.4905
# Epoch 456/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7878 - loss: 0.4679 - precision_3: 0.6751 - recall_4: 0.4949 - val_binary_accuracy: 0.7883 - val_loss: 0.4675 - val_precision_3: 0.6779 - val_recall_4: 0.4935
# Epoch 457/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7889 - loss: 0.4667 - precision_3: 0.6764 - recall_4: 0.4938 - val_binary_accuracy: 0.7882 - val_loss: 0.4674 - val_precision_3: 0.6810 - val_recall_4: 0.4869
# Epoch 458/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7867 - loss: 0.4687 - precision_3: 0.6734 - recall_4: 0.4926 - val_binary_accuracy: 0.7871 - val_loss: 0.4674 - val_precision_3: 0.6826 - val_recall_4: 0.4761
# Epoch 459/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7875 - loss: 0.4682 - precision_3: 0.6763 - recall_4: 0.4969 - val_binary_accuracy: 0.7894 - val_loss: 0.4673 - val_precision_3: 0.6754 - val_recall_4: 0.5062
# Epoch 460/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7890 - loss: 0.4663 - precision_3: 0.6762 - recall_4: 0.4980 - val_binary_accuracy: 0.7881 - val_loss: 0.4673 - val_precision_3: 0.6804 - val_recall_4: 0.4874
# Epoch 461/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7878 - loss: 0.4674 - precision_3: 0.6750 - recall_4: 0.4952 - val_binary_accuracy: 0.7897 - val_loss: 0.4673 - val_precision_3: 0.6742 - val_recall_4: 0.5106
# Epoch 462/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7899 - loss: 0.4659 - precision_3: 0.6785 - recall_4: 0.4989 - val_binary_accuracy: 0.7883 - val_loss: 0.4674 - val_precision_3: 0.6778 - val_recall_4: 0.4939
# Epoch 463/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7881 - loss: 0.4667 - precision_3: 0.6744 - recall_4: 0.4928 - val_binary_accuracy: 0.7876 - val_loss: 0.4673 - val_precision_3: 0.6828 - val_recall_4: 0.4795
# Epoch 464/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7889 - loss: 0.4663 - precision_3: 0.6765 - recall_4: 0.4978 - val_binary_accuracy: 0.7894 - val_loss: 0.4672 - val_precision_3: 0.6744 - val_recall_4: 0.5081
# Epoch 465/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7884 - loss: 0.4673 - precision_3: 0.6766 - recall_4: 0.4950 - val_binary_accuracy: 0.7889 - val_loss: 0.4671 - val_precision_3: 0.6776 - val_recall_4: 0.4984
# Epoch 466/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7880 - loss: 0.4681 - precision_3: 0.6765 - recall_4: 0.4985 - val_binary_accuracy: 0.7885 - val_loss: 0.4672 - val_precision_3: 0.6808 - val_recall_4: 0.4888
# Epoch 467/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7891 - loss: 0.4669 - precision_3: 0.6791 - recall_4: 0.4980 - val_binary_accuracy: 0.7890 - val_loss: 0.4672 - val_precision_3: 0.6802 - val_recall_4: 0.4939
# Epoch 468/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7886 - loss: 0.4670 - precision_3: 0.6777 - recall_4: 0.4981 - val_binary_accuracy: 0.7883 - val_loss: 0.4671 - val_precision_3: 0.6794 - val_recall_4: 0.4902
# Epoch 469/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7877 - loss: 0.4679 - precision_3: 0.6760 - recall_4: 0.4944 - val_binary_accuracy: 0.7887 - val_loss: 0.4671 - val_precision_3: 0.6804 - val_recall_4: 0.4912
# Epoch 470/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - binary_accuracy: 0.7890 - loss: 0.4666 - precision_3: 0.6774 - recall_4: 0.4972 - val_binary_accuracy: 0.7893 - val_loss: 0.4670 - val_precision_3: 0.6757 - val_recall_4: 0.5050
# Epoch 471/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7891 - loss: 0.4671 - precision_3: 0.6776 - recall_4: 0.5012 - val_binary_accuracy: 0.7893 - val_loss: 0.4670 - val_precision_3: 0.6751 - val_recall_4: 0.5064
# Epoch 472/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7890 - loss: 0.4670 - precision_3: 0.6782 - recall_4: 0.5000 - val_binary_accuracy: 0.7883 - val_loss: 0.4670 - val_precision_3: 0.6815 - val_recall_4: 0.4861
# Epoch 473/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7884 - loss: 0.4668 - precision_3: 0.6771 - recall_4: 0.4969 - val_binary_accuracy: 0.7894 - val_loss: 0.4671 - val_precision_3: 0.6780 - val_recall_4: 0.5007
# Epoch 474/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7886 - loss: 0.4663 - precision_3: 0.6763 - recall_4: 0.4989 - val_binary_accuracy: 0.7896 - val_loss: 0.4670 - val_precision_3: 0.6762 - val_recall_4: 0.5054
# Epoch 475/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7886 - loss: 0.4666 - precision_3: 0.6757 - recall_4: 0.4974 - val_binary_accuracy: 0.7886 - val_loss: 0.4670 - val_precision_3: 0.6800 - val_recall_4: 0.4912
# Epoch 476/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7885 - loss: 0.4665 - precision_3: 0.6765 - recall_4: 0.5000 - val_binary_accuracy: 0.7892 - val_loss: 0.4671 - val_precision_3: 0.6732 - val_recall_4: 0.5097
# Epoch 477/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7885 - loss: 0.4667 - precision_3: 0.6759 - recall_4: 0.4953 - val_binary_accuracy: 0.7895 - val_loss: 0.4670 - val_precision_3: 0.6754 - val_recall_4: 0.5069
# Epoch 478/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7895 - loss: 0.4659 - precision_3: 0.6779 - recall_4: 0.4960 - val_binary_accuracy: 0.7897 - val_loss: 0.4669 - val_precision_3: 0.6766 - val_recall_4: 0.5056
# Epoch 479/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7887 - loss: 0.4669 - precision_3: 0.6768 - recall_4: 0.4997 - val_binary_accuracy: 0.7879 - val_loss: 0.4671 - val_precision_3: 0.6795 - val_recall_4: 0.4875
# Epoch 480/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7889 - loss: 0.4661 - precision_3: 0.6772 - recall_4: 0.4970 - val_binary_accuracy: 0.7890 - val_loss: 0.4669 - val_precision_3: 0.6774 - val_recall_4: 0.4992
# Epoch 481/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7882 - loss: 0.4675 - precision_3: 0.6768 - recall_4: 0.4974 - val_binary_accuracy: 0.7902 - val_loss: 0.4670 - val_precision_3: 0.6729 - val_recall_4: 0.5173
# Epoch 482/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7888 - loss: 0.4668 - precision_3: 0.6769 - recall_4: 0.4977 - val_binary_accuracy: 0.7880 - val_loss: 0.4668 - val_precision_3: 0.6808 - val_recall_4: 0.4859
# Epoch 483/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - binary_accuracy: 0.7889 - loss: 0.4667 - precision_3: 0.6780 - recall_4: 0.4989 - val_binary_accuracy: 0.7873 - val_loss: 0.4668 - val_precision_3: 0.6820 - val_recall_4: 0.4789
# Epoch 484/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - binary_accuracy: 0.7887 - loss: 0.4665 - precision_3: 0.6775 - recall_4: 0.4992 - val_binary_accuracy: 0.7894 - val_loss: 0.4667 - val_precision_3: 0.6797 - val_recall_4: 0.4971
# Epoch 485/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - binary_accuracy: 0.7892 - loss: 0.4662 - precision_3: 0.6780 - recall_4: 0.4967 - val_binary_accuracy: 0.7881 - val_loss: 0.4667 - val_precision_3: 0.6808 - val_recall_4: 0.4866
# Epoch 486/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - binary_accuracy: 0.7891 - loss: 0.4661 - precision_3: 0.6784 - recall_4: 0.4978 - val_binary_accuracy: 0.7897 - val_loss: 0.4667 - val_precision_3: 0.6784 - val_recall_4: 0.5016
# Epoch 487/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - binary_accuracy: 0.7883 - loss: 0.4675 - precision_3: 0.6771 - recall_4: 0.4988 - val_binary_accuracy: 0.7903 - val_loss: 0.4667 - val_precision_3: 0.6751 - val_recall_4: 0.5132
# Epoch 488/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7887 - loss: 0.4671 - precision_3: 0.6765 - recall_4: 0.4983 - val_binary_accuracy: 0.7904 - val_loss: 0.4667 - val_precision_3: 0.6726 - val_recall_4: 0.5189
# Epoch 489/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7894 - loss: 0.4660 - precision_3: 0.6774 - recall_4: 0.4999 - val_binary_accuracy: 0.7902 - val_loss: 0.4667 - val_precision_3: 0.6757 - val_recall_4: 0.5107
# Epoch 490/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7887 - loss: 0.4665 - precision_3: 0.6757 - recall_4: 0.4990 - val_binary_accuracy: 0.7896 - val_loss: 0.4667 - val_precision_3: 0.6798 - val_recall_4: 0.4979
# Epoch 491/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7896 - loss: 0.4656 - precision_3: 0.6795 - recall_4: 0.5016 - val_binary_accuracy: 0.7889 - val_loss: 0.4666 - val_precision_3: 0.6807 - val_recall_4: 0.4918
# Epoch 492/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7893 - loss: 0.4656 - precision_3: 0.6779 - recall_4: 0.4983 - val_binary_accuracy: 0.7904 - val_loss: 0.4666 - val_precision_3: 0.6755 - val_recall_4: 0.5126
# Epoch 493/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7889 - loss: 0.4669 - precision_3: 0.6775 - recall_4: 0.5018 - val_binary_accuracy: 0.7880 - val_loss: 0.4667 - val_precision_3: 0.6843 - val_recall_4: 0.4792
# Epoch 494/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7893 - loss: 0.4660 - precision_3: 0.6773 - recall_4: 0.4963 - val_binary_accuracy: 0.7897 - val_loss: 0.4666 - val_precision_3: 0.6755 - val_recall_4: 0.5080
# Epoch 495/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7891 - loss: 0.4658 - precision_3: 0.6762 - recall_4: 0.4975 - val_binary_accuracy: 0.7891 - val_loss: 0.4665 - val_precision_3: 0.6783 - val_recall_4: 0.4978
# Epoch 496/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7898 - loss: 0.4661 - precision_3: 0.6783 - recall_4: 0.4987 - val_binary_accuracy: 0.7903 - val_loss: 0.4665 - val_precision_3: 0.6777 - val_recall_4: 0.5073
# Epoch 497/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7896 - loss: 0.4651 - precision_3: 0.6768 - recall_4: 0.4985 - val_binary_accuracy: 0.7900 - val_loss: 0.4666 - val_precision_3: 0.6758 - val_recall_4: 0.5096
# Epoch 498/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7893 - loss: 0.4658 - precision_3: 0.6782 - recall_4: 0.4996 - val_binary_accuracy: 0.7889 - val_loss: 0.4666 - val_precision_3: 0.6811 - val_recall_4: 0.4914
# Epoch 499/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - binary_accuracy: 0.7898 - loss: 0.4662 - precision_3: 0.6798 - recall_4: 0.4988 - val_binary_accuracy: 0.7883 - val_loss: 0.4669 - val_precision_3: 0.6838 - val_recall_4: 0.4816
# Epoch 500/500
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - binary_accuracy: 0.7884 - loss: 0.4670 - precision_3: 0.6773 - recall_4: 0.4979 - val_binary_accuracy: 0.7898 - val_loss: 0.4665 - val_precision_3: 0.6781 - val_recall_4: 0.5029

# %% [markdown]
# Guardamos el modelo entrenado y generamos las curvas de entrenamiento.

# %%
#Guardamos el modelo entrenado con los hiperparametros óptimos
classifier.save("/home/jupyter-manuel/Digiopt/Models/Classifier_PCA_HyperModel_2.keras")

# %%
##Convertimos los resultados en un DataFrame y representamos las curvas de aprendizaje y la métrica "binary_accuracy"
history_df = pd.DataFrame(history.history)

#Creamos la figura y la grid donde añadir los graficos
figure = plt.figure(figsize = (10, 10)) #Definimos la figura y su tamaño
grid = gridspec.GridSpec(2, 2, width_ratios = [1, 1]) #Definimos la grid de la figuraa junto con el numero de filas y columnas y el ratio de achos de cada columna

#Añadimos el primer grafico al primer espacio de la cuadricula: Curvas de entrenamiento (función de coste)
ax0 = plt.subplot(grid[0])
history_df.loc[:, ["loss", "val_loss"]].plot(ax = ax0) #Con el argumento de la funcion plot() ax = ax0 indicamos que el grafico correspoda el hueco de la grid asociado a ax0
ax0.set_title('Curvas de entrenamiento')

#Añadimos el segundo grafico al segundo hueco de la cuadricula: Bondad de clasificación
ax1 = plt.subplot(grid[1])
history_df.loc[:, ["binary_accuracy", "val_binary_accuracy"]].plot(ax = ax1)
ax1.set_title("Bondad de clasificación")

#Añadimos el tercer grafico al tercer hueco de la cuadricula: Falsos negativos
ax2 = plt.subplot(grid[2])
history_df.loc[:, ["precision_3", "val_precision_3"]].plot(ax = ax2)
ax2.set_title("Precision")

#Añadimos el cuarto gráfico al cuarto hueco de la cuadricula: Falsos positivos
ax3 = plt.subplot(grid[3])
history_df.loc[:, ["recall_4", "val_recall_4"]].plot(ax = ax3)
ax3.set_title("Recall")

#Mostramos el grafico
plt.tight_layout()  # Ajusta automáticamente los parámetros de la subtrama
plt.show()

# %%
##Cargamos el modelo entrenado y congelamos los pesos para que no se puedan modeificcar en posibles procesos de entrenamiento
classifier = load_model("/home/jupyter-manuel/Digiopt/Models/Classifier_PCA_HyperModel.keras", custom_objects = {'Classifier_PCA': Classifier_NN})
classifier.trainable = False

# %%
y_predict = classifier.predict(X_train)
#Crear una figura con dos subplots, uno encima del otro
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
#Distribución de la variable guardada en la primera neurona
axs[0].hist(y_predict, bins=50)
axs[0].set_title("Valores de la funcion sigmoid.")
axs[0].set_xlabel("Values")
axs[0].set_ylabel("Number of examples")
#Boxplot de la variable guardada en la primera neurona
axs[1].boxplot(y_predict, vert=False)
axs[1].set_title('Boxplot de la variable')
axs[1].set_xlabel('Variable')
axs[1].grid(True)
#Ajustar el layout para evitar superposiciones
plt.tight_layout()
#Mostrar la figura
plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721373949.492133 1868158 service.cc:145] XLA service 0x7f2450005520 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1721373949.492200 1868158 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-07-19 07:25:49.505177: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-19 07:25:49.557731: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#    71/17802 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step
# I0000 00:00:1721373949.887315 1868158 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17802/17802 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step

# %% [markdown]
# Genaramos la matriz de confusión para el conjunto de entrenamiento para visualizar los resultados de las predicciones dadas por el modelo.

# %%
##Matriz de confusion para el conjunto de entrenamiento
y_predict_train = classifier.predict(X_train)
y_predict_train = (y_predict_train > 0.5).astype(int) #El valor de 0.5 corresponde al umbral
y_predict_train = pd.DataFrame(y_predict_train, index = y_train.index) #Ponemos los indices a las predicciones los correspondientes de la mestra original para que la tabla cruzada se genere correctamente
#Generación de la tabla cruzada
cross_tab = pd.crosstab(y_train, y_predict_train.iloc[:,0], rownames=['Real'], colnames=['Predicción'], margins=True)
print(y_predict_train.iloc[:,0].value_counts())
print(y_train.value_counts())
print(cross_tab)
print("\n")
print_stats(y_predict_train, y_train)
# Out:
# 17802/17802 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step
# 0
# 0    399652
# 1    169985
# Name: count, dtype: int64
# Test_W
# 0.0    406884
# 1.0    162753
# Name: count, dtype: int64
# Predicción       0       1     All
# Real
# 0.0         371816   35068  406884
# 1.0          27836  134917  162753
# All         399652  169985  569637
#
#
# Accuracy: 0.8895717799230036
# Precision: 0.7936994440685943
# Recall: 0.8289678224057314
# F1 score: 0.8109503573382061

# %% [markdown]
# Para una muestra test del conjunto de señales original, y completamente independiente de la muestra de datos empleada para el entrenamiento y validación, realizamos todo el proceso desde el conjunto de datos en bruto hasta obtener los resultados de la clasificación, junto con los diferentes indicadores de la clasificación. Se le aplicara a los datos la reduccion de la dimensión, el test de Wilcoxon y la red neronal de comparación. Esta muestra test no se va a submuestrear.

# %%
#Extraemos el conjunto de datos test y lo normalizamos el conjunto de datos test extraido de la muestra completa de señales
core_test = core_signals.iloc[-500:, :]
test_norm = normalizacion(core_test)

#Realizamos el emparejamiento de las señales
start = time.time()
paired_index_test, test_combined = parallel_paired_pulses(test_norm, return_df = True)
end = time.time()
##Determinamos el tiempo de ejecucion
horas, minutos, segundos = convertir_segundos(end - start)
print(f"Tiempo requerido para emparejar las señales: \n {horas} horas, {minutos} minutos, {segundos} segundos")

#Una vez emparejadas las señales procedemos a obtener los resultados del test de Wilcoxon
start = time.time()
test_compared_W = parallel_compare_pulses(test_combined)
end = time.time()
##Determinamos el tiempo de ejecucion
horas, minutos, segundos = convertir_segundos(end - start)
print(f"Tiempo requerido para comparar las señales: \n {horas} horas, {minutos} minutos, {segundos} segundos")
display(test_compared_W.value_counts("Test_W"))

##Extraemos la caracteristica que pretendemos predecir, que en este caso es la evaluacion del test de wilcoxon para pares de señales, que estan contenidas en el DataFrame test_compared_W
test_target_w = test_compared_W["Test_W"]

##Pasamos a reducir la dimensión de las señales que vamos a emplear como muestra en el espacio de dimensión reducida
#Como método de reducción de la dimensión vamos a emplear el análisis de componetes principales (PCA).
encoded_test = pca.transform(test_norm)
#Lo convertimos en un DataFrame por comodidad
encoded_test_df = pd.DataFrame(encoded_test)

##Llamamos a la función parallel_paired_pulses() para generar todas las posibles combinaciones
start = time.time()
index_paired, test_paired_pulses = parallel_paired_pulses(encoded_test_df, return_df = True)
end = time.time()
#Determinamos el tiempo de ejecución
horas, minutos, segundos = convertir_segundos(end - start)
print(f"Tiempo requerido para emparejar las señales en el espacio de dimension latente: \n {horas} horas, {minutos} minutos, {segundos} segundos")

##Una vez generados los pares de pulsos, añadimos la columna asocada a la comparación dada por el test de Wilcoxon
test_paired_pulses["Test_W"] = test_target_w

##Eliminamos las columnas cuyas neuronas no guardan información, es decir, que todas las filas son cero
#Eliminar columnas donde todas las filas son ceros, generando el DataFrame con el que vamos a trabajar.
df = test_paired_pulses.loc[:, ~(test_paired_pulses == 0).all()]
display(df)

##Generamos los atributos, las etiquetas y los ids para el conjunto de datos test con el que estamos validando la red neuronal
X_test = df.drop(["id_1", "id_2", "Test_W"], axis = 1)
ids_test = df[["id_1", "id_2"]]
y_test = df["Test_W"]
# Out:
# Tiempo requerido para emparejar las señales:
#  0.0 horas, 0.0 minutos, 24.95949625968933 segundos
# Tiempo requerido para comparar las señales:
#  0.0 horas, 0.0 minutos, 23.02907633781433 segundos
# Test_W
# 0    111818
# 1     12932
# Name: count, dtype: int64
# Tiempo requerido para emparejar las señales en el espacio de dimension latente:
#  0.0 horas, 0.0 minutos, 11.541874885559082 segundos
#         id_1  id_2         0         1         2         3         4  \
# 0          0     1  0.179656  0.149715 -0.143068  0.191007 -0.036161
# 1          0     2  0.179656  0.149715 -0.143068  0.191007 -0.036161
# 2          0     3  0.179656  0.149715 -0.143068  0.191007 -0.036161
# 3          0     4  0.179656  0.149715 -0.143068  0.191007 -0.036161
# 4          0     5  0.179656  0.149715 -0.143068  0.191007 -0.036161
# ...      ...   ...       ...       ...       ...       ...       ...
# 124745   496   498 -0.041123  0.177968  0.107633 -0.026967 -0.128784
# 124746   496   499 -0.041123  0.177968  0.107633 -0.026967 -0.128784
# 124747   497   498 -0.052013  0.314239 -0.162049  0.027555  0.064230
# 124748   497   499 -0.052013  0.314239 -0.162049  0.027555  0.064230
# 124749   498   499 -0.064061  0.357273 -0.069615  0.007972 -0.004151
#
#                5         6         7  ...        11        12        13  \
# 0       0.109914  0.022878 -0.011737  ...  0.062153 -0.058716 -0.009655
# 1       0.109914  0.022878 -0.011737  ...  0.256869 -0.192800  0.139583
# 2       0.109914  0.022878 -0.011737  ...  0.063125  0.050097 -0.033201
# 3       0.109914  0.022878 -0.011737  ... -0.263012  0.098644 -0.010213
# 4       0.109914  0.022878 -0.011737  ... -0.420622  0.062594  0.163537
# ...          ...       ...       ...  ...       ...       ...       ...
# 124745 -0.018850  0.039022 -0.015140  ...  0.357273 -0.069615  0.007972
# 124746 -0.018850  0.039022 -0.015140  ...  0.250740 -0.137776  0.110642
# 124747  0.034600 -0.020970  0.013155  ...  0.357273 -0.069615  0.007972
# 124748  0.034600 -0.020970  0.013155  ...  0.250740 -0.137776  0.110642
# 124749  0.004286  0.029624  0.002908  ...  0.250740 -0.137776  0.110642
#
#               14        15        16        17        18        19  Test_W
# 0       0.190124  0.063066 -0.017029 -0.033681  0.023864  0.065089       0
# 1       0.036323  0.051563  0.016888 -0.007977 -0.000799 -0.028588       1
# 2      -0.017017  0.074603  0.006521 -0.014414  0.002373 -0.021593       0
# 3      -0.004528 -0.024000 -0.100937 -0.040377 -0.034144  0.017678       0
# 4       0.020454  0.083363 -0.060171  0.014236  0.003804  0.009252       0
# ...          ...       ...       ...       ...       ...       ...     ...
# 124745 -0.004151  0.004286  0.029624  0.002908  0.009369  0.001432       0
# 124746  0.073410  0.024176  0.039957 -0.029947 -0.019029 -0.041431       0
# 124747 -0.004151  0.004286  0.029624  0.002908  0.009369  0.001432       0
# 124748  0.073410  0.024176  0.039957 -0.029947 -0.019029 -0.041431       1
# 124749  0.073410  0.024176  0.039957 -0.029947 -0.019029 -0.041431       0
#
# [124750 rows x 23 columns]

# %%
##Calculamos las predicciones del modelo dadas para el conjunto de datos test
y_predict_test = classifier.predict(X_test)
y_predict_test = (y_predict_test > 0.5).astype(int)
#Convertimos las predicciones a un DataFrame y mostramos los resultados obtenidos
y_predict_test = pd.DataFrame(y_predict_test, index = y_test.index)
display(y_predict_test.value_counts())
display(y_test.value_counts())

##Generación de la tabla cruzada
cross_tab = pd.crosstab(y_test, y_predict_test.iloc[:,0], rownames=['Real'], colnames=['Predicción'], margins=True)
print(cross_tab)

#Llamamos a la funcion para calular las stats de la clasificación
print("\n")
print_stats(y_predict_test, y_test)
# Out:
# 3899/3899 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 0
# 0    104195
# 1     20555
# Name: count, dtype: int64
# Test_W
# 0    111818
# 1     12932
# Name: count, dtype: int64
# Predicción       0      1     All
# Real
# 0           101388  10430  111818
# 1             2807  10125   12932
# All         104195  20555  124750
#
#
# Accuracy: 0.8938917835671343
# Precision: 0.4925808805643396
# Recall: 0.7829415403649861
# F1 score: 0.6047122764057694

# %% [markdown]
# Calculamos la curva ROC como métrica de clasificación del modelo para poder comparar el desempeño de la red neuronal a la hora de clasificar, de tal manera que podamos comparar los resultados entre modelos.

# %%
#Calcular los puntos de la curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_predict_test)

#Calcular el AUC
auc = roc_auc_score(y_test, y_predict_test)

#Graficar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color = 'blue', lw = 2, label = 'Curva ROC (AUC = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color = 'gray', linestyle = '--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ratio Falsos Positivos')
plt.ylabel('Ratio Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# Generamos la imagen correspondientes a la arquitectura del modelo de clasificación usado.

# %%
#Generacion de graficos de arquitecturas
import graphviz
import pydotplus
#Generacion del grafico en un fichero
#Arqutectura encoder
plot_model(classifier.classifier, to_file = '/home/jupyter-manuel/Digiopt/Imagenes_arquitecturas/Classifier_PCA_2.png', show_shapes = True, show_layer_activations = True)

#Mostrar la imagen del gráfico
Image(filename = '/home/jupyter-manuel/Digiopt/Imagenes_arquitecturas/Classifier_PCA_2.png')

# %% [markdown]
# Se cierra la sesión abierta de Tensorflow de tal manera que se libera el espacio de memoria de GPU reservado.

# %%
##Ejecutar siempre que se quiera liberar el espacio de la GPU y al final de cada scrip
cuda.select_device(0)
cuda.close()
